# %%
import subprocess 
import torch as ch
from torch import Tensor
import torch.linalg as LA
from torch.distributions import Uniform
from torch.distributions.multivariate_normal import MultivariateNormal
import pandas as pd
import numpy as np
import csv
import json
from cox.utils import Parameters
from cox.store import Store

from cox.readers import CollectionReader
import os
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
import math 

import sys 
sys.path.append('../..')
from delphi.stats.linear_regression import TruncatedRegression
from delphi.oracle import Left
from delphi.utils import constants as consts
from delphi.utils.helpers import setup_store_with_metadata

OUT_DIR = '/home/gridsan/stefanou/Regression/'
TABLE_NAME = 'logs'

# set environment variable so that stores can create output files
os.environ['HDF5_USE_FILE_LOCKING'] = 'FALSE'

# %%
args = Parameters({
    "bias": True,
    "samples": 1000,
    "c": 0,
    "batch_size": 5,
    "lr": 1e-1,
    "var_lr": 1e-2,
    "var_": 1,
    "trials": 3,
    "norm": False,
    "workers": 8,
    "steps": 1000,
    "x_lower": -10,
    "x_upper": 10,
    "lower": -1,
    "upper": 1,
    "device": "cuda",
    "num_samples": 100,
})
mse_loss = ch.nn.MSELoss()

# %% [markdown]
# I will start by generating the ground-truth for our expriment.

# %%
# distribution for generating feature vectors
d, k = 1, 1
w = Uniform(-1, 1)
m = MultivariateNormal(ch.zeros(d), ch.eye(d)/d)
# m = Uniform(-5, 5)
phi = Left(Tensor([0.0]))

# generate ground truth
gt = ch.nn.Linear(in_features=k, out_features=1)
gt.weight = ch.nn.Parameter(w.sample(ch.Size([k, d])))

# gt.bias = ch.nn.Parameter(ch.ones(1, 1)) if args.bias else None
gt.bias = ch.nn.Parameter(w.sample(ch.Size([1, 1]))) if args.bias else None

print("gt weight: ", gt.weight)
print("gt bias: ", gt.bias)

# create base classifier
with ch.no_grad():
    # generate data
    X = m.sample(ch.Size([args.samples, d])) if isinstance(m, Uniform) else m.sample(ch.Size([args.samples]))

    y = gt(X)

noise_var = Tensor([5.0])[...,None]
# remove synthetic data from the computation graph
with ch.no_grad():
    # add noise to ground-truth pedictions
    noised = y + ch.sqrt(noise_var) * ch.randn(X.size(0), 1)
    # truncate based off of the standardized data
    indices = phi(noised).nonzero(as_tuple=False).flatten()
    y_trunc, x_trunc = noised[indices], X[indices]
    alpha = Tensor([y_trunc.size(0) / args.samples])
    print("alpha: ", alpha)
    
# ground-truth OLS
gt_ols = LinearRegression()
gt_ols.fit(X, noised)
print("gt ols coef: ", gt_ols.coef_)
print("gt ols intercept: ", gt_ols.intercept_)

trunc_ols = LinearRegression()
trunc_ols.fit(x_trunc, y_trunc)
trunc_ols_pred = trunc_ols.predict(x_trunc)
print("trunc ols coef: ", trunc_ols.coef_)
print("trunc ols intercept: ", trunc_ols.intercept_)

# data for plotting regressions
unnorm_data = np.linspace(-5, 5, 100).reshape(100, 1)
norm_data = np.linspace(-1, 1, 100).reshape(100, 1)

ax = plt.subplot(1, 1, 1)
plt.scatter(X, noised)
plt.scatter(x_trunc, y_trunc)
plt.plot(unnorm_data, gt_ols.predict(unnorm_data), color='green', label='gt ols')
plt.plot(unnorm_data, trunc_ols.predict(unnorm_data), color='red', label='trunc ols')
plt.legend()
plt.title("Empirical and Ground Truth Dataset and Model")
ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# gt weight:  Parameter containing:
# tensor([[0.8821]], requires_grad=True)
# gt bias:  Parameter containing:
# tensor([[0.0404]], requires_grad=True)
# alpha:  tensor([0.5180])
# gt ols coef:  [[0.9019689]]
# gt ols intercept:  [0.00513036]
# trunc ols coef:  [[0.31445312]]
# trunc ols intercept:  [1.6480032]
# Text(0, 0.5, 'y')

# %% [markdown]
# Now, we want to standardize our truncated dataset, so that our empirical estimates are located on the l2 ball. First we will divide all of our covariate features by $B\sqrt{k}$, so that all of our covariate features $||x_{i}||_{2}^{2} \leq 1$, and reside on the $\ell_{2}$ ball. This way the norm of $w$ will be multiplied by $B\sqrt{k}$.

# %%
max_x_trunc_norm = LA.norm(x_trunc, dim=-1, ord=float('inf')).max()
print("max truncated x norm", max_x_trunc_norm)

beta = max_x_trunc_norm*math.sqrt(X.size(1))
print("beta: ", beta)

x_trunc_norm = x_trunc / beta
print("x max l2: ", x_trunc_norm.norm(dim=-1).max())
# Out:
# max truncated x norm tensor(2.9651)
# beta:  tensor(2.9651)
# x max l2:  tensor(1.)

# %% [markdown]
# We now observe that the norm of the truncated x covariates is bounded by 1. So, now we will standardze our dependent variable so that it's ground-truth takes the form of the linear regression latent variable model with noise variance of 1. First, let's calculate the predicted values from our naive ols regression on teh truncated data.

# %% [markdown]
# First, we will standardize our data for the case where we assume that the empirical noise variance is the underlying noise variance of the ground truth regression.

# %%
emp_noise_var = (y_trunc - trunc_ols_pred).var(0)
print("emp noise var: ", emp_noise_var)

emp_stand_y_trunc = y_trunc / ch.sqrt(emp_noise_var)
trunc_noise_var = (emp_stand_y_trunc - (trunc_ols_pred / ch.sqrt(emp_noise_var))).var(0)
print("trunc reg noise var: ", trunc_noise_var)

new_X, emp_stand_noised = X / beta, noised / ch.sqrt(emp_noise_var)

gt_emp_stand = LinearRegression()
gt_emp_stand.fit(new_X, emp_stand_noised)

trunc_emp_stand_ols = LinearRegression()
trunc_emp_stand_ols.fit(x_trunc_norm, emp_stand_y_trunc)

ax = plt.subplot(1, 1, 1)
plt.scatter(new_X, emp_stand_noised, label='entire dataset', alpha=.75)
plt.scatter(x_trunc_norm, emp_stand_y_trunc, label='truncated dataset', alpha=.75)
plt.plot(norm_data, gt_emp_stand.predict(norm_data), color='green', label='gt ols')
plt.plot(norm_data, trunc_emp_stand_ols.predict(norm_data), color='red', label='trunc ols')
plt.legend()
plt.title('Y Scaled by Empirical Noise Variance')
ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# emp noise var:  tensor([1.6791])
# trunc reg noise var:  tensor([1.])
# Text(0, 0.5, 'y')

# %% [markdown]
# First, we will standardize our data for the case where we assume that wee know the underlying ground-truth noise variance.

# %%
stand_noised, stand_y_trunc = noised / ch.sqrt(noise_var), y_trunc / ch.sqrt(noise_var)

gt_stand = LinearRegression()
gt_stand.fit(new_X, stand_noised)

trunc_stand_ols = LinearRegression()
trunc_stand_ols.fit(x_trunc_norm, stand_y_trunc)

ax = plt.subplot(1, 1, 1)
plt.scatter(new_X, stand_noised, label='entire dataset', alpha=.75)
plt.scatter(x_trunc_norm, stand_y_trunc, label='truncated dataset', alpha=.75)
plt.plot(norm_data, gt_stand.predict(norm_data), color='green', label='gt ols')
plt.plot(norm_data, trunc_stand_ols.predict(norm_data), color='red', label='trunc ols')
plt.legend()
plt.title("Y Scaled by Ground-Truth Noise Variance")
ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# Truncated Regression with Known Empirical Variance

# %%
trunc_reg = TruncatedRegression(phi=phi, alpha=alpha, bias=True, unknown=False, val=100, bs=10, n=1000, tol=1e-2)
known_emp_res = trunc_reg.fit(x_trunc_norm, emp_stand_y_trunc)
known_emp_w_unnorm, known_emp_bias_unnorm = (known_emp_res.weight * ch.sqrt(emp_noise_var)) / beta, (known_emp_res.bias * ch.sqrt(emp_noise_var))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))

# %%
ax = plt.subplot(1, 1, 1)
plt.scatter(new_X, emp_stand_noised, label='entire dataset', alpha=.75)
plt.scatter(x_trunc_norm, emp_stand_y_trunc, label='truncated dataset', alpha=.75)
plt.plot(norm_data, trunc_emp_stand_ols.predict(norm_data), color='r', label='ols')
plt.plot(norm_data, gt_emp_stand.predict(norm_data), color='green', label='gt')
plt.plot(norm_data, known_emp_res(Tensor(norm_data)).detach().numpy(), label='known emp', color='blue')
plt.legend()
plt.title("Empirical Known Noise Variance Results - Normalized")
ax.set_xlabel("x")
ax.set_ylabel("y")
plt.show()

ax = plt.subplot(1, 1, 1)
plt.plot(unnorm_data, trunc_ols.predict(unnorm_data), color='red', label='ols')
plt.plot(unnorm_data, (Tensor(unnorm_data)@known_emp_w_unnorm + known_emp_bias_unnorm).detach().numpy(), label='known', color='blue')
plt.plot(unnorm_data, gt_ols.predict(unnorm_data), color='green', label='gt')
plt.scatter(X, noised, label='entire dataset')
plt.scatter(x_trunc, y_trunc, label='truncated dataset')
plt.legend()
plt.title("Empirical Known Noise Variance Results - UnNormalized")
ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# Truncated Regression with Known Variance

# %%
trunc_reg = TruncatedRegression(phi=phi, alpha=alpha, bias=True, unknown=False, val=100, bs=10, n=1000, tol=1e-2)
known_res = trunc_reg.fit(x_trunc_norm, stand_y_trunc)
known_weight_unnorm, known_bias_unnorm = (known_res.weight * ch.sqrt(noise_var)) / beta, known_res.bias * ch.sqrt(noise_var)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))

# %%
ax = plt.subplot(1, 1, 1)
plt.scatter(new_X, stand_noised, label='entire dataset', alpha=.75)
plt.scatter(x_trunc_norm, stand_y_trunc, label='truncated dataset', alpha=.75)
plt.plot(norm_data, trunc_stand_ols.predict(norm_data), color='r', label='ols')
plt.plot(norm_data, gt_stand.predict(norm_data), color='green', label='gt')
plt.plot(norm_data, known_res(Tensor(norm_data)).detach().numpy(), label='known', color='blue')
plt.legend()
plt.title("Known Noise Variance - Normalized")
ax.set_xlabel("x")
ax.set_ylabel("y")
plt.show()

ax = plt.subplot(1, 1, 1)
plt.scatter(X, noised, label='entire dataset', alpha=.75)
plt.scatter(x_trunc, y_trunc, label='truncated dataset', alpha=.75)
plt.plot(unnorm_data, trunc_ols.predict(unnorm_data), color='r', label='ols')
plt.plot(unnorm_data, gt_ols.predict(unnorm_data), color='green', label='gt')
plt.plot(unnorm_data, (Tensor(unnorm_data)@known_weight_unnorm + known_bias_unnorm).detach().numpy(), label='known', color='blue')
plt.legend()
plt.title("Known Noise Variance - UnNormalized")
ax.set_xlabel("x")
ax.set_ylabel("y")
plt.show()

# %% [markdown]
# Truncated Regression with Unknown Noise Variance

# %%
trunc_reg = TruncatedRegression(phi=phi, alpha=alpha, bias=True, unknown=True, bs=10, n=1000, tol=1e-2)
unknown_res = trunc_reg.fit(x_trunc_norm, emp_stand_y_trunc)
unknown_var = unknown_res.lambda_.inverse()
unknown_weight_unnorm, unknown_bias_unnorm = (((unknown_res.weight * unknown_var) * ch.sqrt(emp_noise_var)) / beta).detach().numpy(), ((unknown_res.bias * unknown_var) * ch.sqrt(emp_noise_var)).detach().numpy()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=52.0), HTML(value='')))

# %%
ax = plt.subplot(1, 1, 1)
plt.scatter(new_X, emp_stand_noised, label='entire dataset', alpha=.75)
plt.scatter(x_trunc_norm, emp_stand_y_trunc, label='truncated dataset', alpha=.75)
plt.plot(norm_data, trunc_emp_stand_ols.predict(norm_data), color='r', label='ols')
plt.plot(norm_data, gt_emp_stand.predict(norm_data), color='green', label='gt')
plt.plot(norm_data, unknown_res(Tensor(norm_data)).detach().numpy(), label='unknown', color='blue')
plt.legend()
ax.set_title("Unknown Noise Variance - Normalized")
ax.set_xlabel("x")
ax.set_ylabel("y")
plt.show()

ax = plt.subplot(1, 1, 1)
plt.scatter(X, noised, label='entire dataset', alpha=.75)
plt.scatter(x_trunc, y_trunc, label='truncated dataset', alpha=.75)
plt.plot(unnorm_data, trunc_ols.predict(unnorm_data), label='ols', color='red')
plt.plot(unnorm_data, gt_ols.predict(unnorm_data), color='g', label='gt')
plt.plot(unnorm_data, (Tensor(unnorm_data)@unknown_weight_unnorm + unknown_bias_unnorm), color='blue', label='unknown')
plt.legend()
ax.set_title("Unknown Noise Variance - UnNormalized")
ax.set_xlabel("x")
ax.set_ylabel("y")
plt.show()

# %% [markdown]
# # Truncate at Zero and Run for High Variance

# %%
args.__setattr__('batch_size', 10)
args.__setattr__('steps', 1500)
args.__setattr__('step_lr', 100)
args.__setattr__('step_lr_gamma', .9)
args.__setattr__('custom_lr_multiplier', None)
args.__setattr__('tol', 1e-2)
args.__setattr__('trials', 3)
args.__setattr__('var_lr', 1e-2)
args.__setattr__('samples', 10000)

EXP = 'ConvergenceTestn100VarLr1e-1'

# %%
 # expriment parameters
w_lower, w_upper = -1, 1
d, k = 1, 1

for i in range(args.trials):
    # create store and add table
    store = Store(OUT_DIR + EXP)
    store.add_table(TABLE_NAME, { 
        'ols_r2': float,
        'ols_param_mse': float,
        'ols_var_l1': float,
#         'known_emp_r2': float,
#         'known_emp_param_mse': float,
#         'known_emp_time': int,
        'known_r2': float,
        'known_param_mse': float,
        'known_time': int,
        'unknown_r2': float, 
        'unknown_param_mse': float,
        'unknown_var_l1': float,
        'unknown_time': int,
        'alpha': float, 
        'num_samples': int,
        'noise_scale': float, 
    })

    # distribution for generating feature vectors
    w = Uniform(w_lower, w_upper)
    dist = MultivariateNormal(ch.zeros(d), ch.eye(d)/d)
    phi = Left(Tensor([0.0]))
    
    # generate ground truth
    gt = ch.nn.Linear(in_features=d, out_features=k)
    gt.weight = ch.nn.Parameter(w.sample(ch.Size([k, d])))
    gt.bias = ch.nn.Parameter(w.sample(ch.Size([1, 1]))) if args.bias else None
    
    # create base classifier
    with ch.no_grad():
        # generate data
        X = dist.sample(ch.Size([args.samples]))
        y = gt(X)
        
    for noise_var in range(1, 11): 
        noise_var = Tensor([noise_var])[None,...]
        # add noise to ground-truth pedictions
        noised = y + ch.sqrt(noise_var)*ch.randn(X.size(0), 1)
        # truncate based off of the standardized data
        indices = phi(noised).nonzero(as_tuple=False).flatten()
        y_trunc, x_trunc = noised[indices], X[indices]
        alpha = Tensor([y_trunc.size(0) / args.samples])
        
        # normalize x features so that ||x_{i}||_{2}^{2} <= 1
        l_inf = LA.norm(x_trunc, dim=-1, ord=float('inf')).max() # find max l_inf
        # calculate normalizing constant
        beta = l_inf*math.sqrt(d)
        """
        Divide input features by normalizing constant. By doing so, 
        the weights will be increased by a magnitude of beta.
        """
        x_trunc_norm = x_trunc / beta
         # normalize entire dataset by beta
        x_norm = X / beta
        
        # ground-truth ols
        gt_ols = LinearRegression()
        gt_ols.fit(X, noised)
        gt_params = ch.cat([Tensor(gt_ols.coef_).T, Tensor(gt_ols.intercept_)[..., None]]).flatten()
        
        # empirical linear regression
        ols = LinearRegression() 
        ols.fit(x_trunc, y_trunc)
        ols_var = ch.var(Tensor(ols.predict(x_trunc)) - y_trunc, dim=0)[..., None]
        ols_params = ch.cat([Tensor(ols.coef_).T, Tensor(ols.intercept_)[..., None]]).flatten()
        # check r2 for entire dataset
        ols_pred = ols.predict(X)

        # ols results
        store[TABLE_NAME].update_row({
            'ols_r2': r2_score(noised.flatten(), ols_pred.flatten()), 
            'ols_var_l1': ch.abs(ols_var - noise_var),
            'ols_param_mse': mse_loss(ols_params, gt_params),
        })
        
        """
        Run dataset on truncated regression with known variance, while 
        assuming that the empirical noise variance is the underlying noise 
        variance of our linear regression. This means that we want to standardize 
        our dependent variable by the empirical noise variance. 
        """
        # variance of the residuals
        emp_noise_var = (y_trunc - ols.predict(x_trunc_norm)).var(0)
        # standardize y trunc by the empirical noise variance
        emp_stand_y_trunc = y_trunc / ch.sqrt(emp_noise_var)
#         # standardize noised by the empirical noise variance
#         emp_stand_noised = noised / ch.sqrt(emp_noise_var)
        
#         trunc_reg = TruncatedRegression(phi=phi, alpha=alpha, args=args, bias=args.bias, var=ch.ones(1))
#         st = datetime.datetime.now()
#         known_emp_results = trunc_reg.fit(x_trunc, y_trunc)
#         w, w0 = (known_emp_results.weight.detach().cpu()), known_emp_results.bias.detach().cpu()[..., None]
#         known_emp_params = ch.cat([w, w0], dim=1).flatten()
#         # known emp results
#         store[TABLE_NAME].update_row({
#             'known_emp_r2': r2_score(noised.flatten(), X@w.T + w0), 
#             'known_emp_param_mse': mse_loss(known_emp_params, gt_params),
#             'known_emp_time': int((datetime.datetime.now() - st).total_seconds()), 
#         })
        
        """
        Run dataset on truncated regression with known variance. This means that we want to standardize 
        our dependent variable by the true noise variance. 
        """
        # standardize y trunc by the empirical noise variance
        stand_y_trunc = y_trunc / math.sqrt(noise_var)
        # standardize noised by the empirical noise variance
        stand_noised = noised / math.sqrt(noise_var)
        trunc_reg = trunc_reg = TruncatedRegression(phi=phi, alpha=alpha, bias=True, unknown=False, bs=10, n=100, tol=1e-2)
        st = datetime.datetime.now()
        known_results = trunc_reg.fit(x_trunc_norm, stand_y_trunc)
        w, w0 = (known_results.weight.detach().cpu() * math.sqrt(noise_var)) / beta, known_results.bias.detach().cpu()[..., None] * math.sqrt(noise_var)
        known_params = ch.cat([w, w0], dim=1).flatten()
        # known results
        store[TABLE_NAME].update_row({
            'known_r2': r2_score(noised.flatten(), X@w.T + w0), 
            'known_param_mse': mse_loss(known_params, gt_params),
            'known_time': int((datetime.datetime.now() - st).total_seconds()), 
        })
        
        
        # truncated regression with unknown variance
        trunc_reg = TruncatedRegression(phi=phi, alpha=alpha, bias=True, unknown=True, bs=10, n=100, tol=5e-2)
        st = datetime.datetime.now()
        unknown_results = trunc_reg.fit(x_trunc_norm, emp_stand_y_trunc)

        var_ = unknown_results.lambda_.inverse()
        unknown_var = var_ * emp_noise_var
        w, w0 = (((unknown_results.weight * var_) * ch.sqrt(emp_noise_var)) / beta).detach(), ((unknown_results.bias * ch.sqrt(emp_noise_var))).detach()[None,...]
        unknown_params = ch.cat([w, w0], dim=1).flatten()

        # known emp results
        store[TABLE_NAME].update_row({
            'unknown_r2': r2_score(noised.flatten(), X@w.T + w0), 
            'unknown_param_mse': mse_loss(unknown_params, gt_params),
            'unknown_var_l1': float(ch.abs(unknown_var - noise_var)),
            'unknown_time': int((datetime.datetime.now() - st).total_seconds()), 
        })
        
        
        # add additional exp data to store
        store[TABLE_NAME].update_row({ 
            'alpha': float(alpha.flatten()),
            'num_samples': x_trunc.size(0),
            'noise_scale': noise_var, 
        })

        # append row to table
        store[TABLE_NAME].flush_row()
    store.close()
# Out:
# Logging in: /home/gridsan/stefanou/Regression/ConvergenceTestn100VarLr1e-1/36671598-9051-45e7-87d0-5567f70afa87
# 100 steps | grad: tensor([0.0398])
# 200 steps | grad: tensor([0.0184])
# 300 steps | grad: tensor([-0.0196])
# 400 steps | grad: tensor([-0.0171])
# 500 steps | grad: tensor([0.0360])
# 600 steps | grad: tensor([0.0069])
# 100 steps | grad: tensor([ 0.3320, -1.1275])
# 200 steps | grad: tensor([ 0.0499, -0.1351])
# 300 steps | grad: tensor([ 0.0455, -0.1522])
# 400 steps | grad: tensor([ 0.0634, -0.2693])
# 500 steps | grad: tensor([ 0.0935, -0.3441])
# 600 steps | grad: tensor([-0.0174,  0.0213])
# 100 steps | grad: tensor([0.0226])
# 200 steps | grad: tensor([0.1191])
# 300 steps | grad: tensor([0.0597])
# 400 steps | grad: tensor([0.0585])
# 500 steps | grad: tensor([0.1024])
# 600 steps | grad: tensor([0.0463])
# 700 steps | grad: tensor([0.0358])
# 800 steps | grad: tensor([0.0751])
# 900 steps | grad: tensor([0.0798])
# 1000 steps | grad: tensor([0.0875])
# 1100 steps | grad: tensor([0.0769])
# 1200 steps | grad: tensor([0.0499])
# 100 steps | grad: tensor([-0.1835,  0.4683])
# 200 steps | grad: tensor([ 0.0177, -0.0641])
# 300 steps | grad: tensor([-0.1259,  0.4121])
# 400 steps | grad: tensor([-0.2217,  0.6563])
# 500 steps | grad: tensor([ 0.0071, -0.0952])
# 600 steps | grad: tensor([-0.0762,  0.2775])
# 700 steps | grad: tensor([-0.1382,  0.4490])
# 800 steps | grad: tensor([-0.0272,  0.0470])
# 100 steps | grad: tensor([0.0199])
# 200 steps | grad: tensor([0.0197])
# 300 steps | grad: tensor([0.0137])
# 400 steps | grad: tensor([-0.0305])
# 500 steps | grad: tensor([-0.0231])
# 600 steps | grad: tensor([0.0214])
# 700 steps | grad: tensor([0.0378])
# 800 steps | grad: tensor([0.0309])
# 900 steps | grad: tensor([0.0246])
# 1000 steps | grad: tensor([0.0002])
# 100 steps | grad: tensor([-0.0925,  0.1727])
# 200 steps | grad: tensor([ 0.0103, -0.1197])
# 300 steps | grad: tensor([ 0.0120, -0.2026])
# 400 steps | grad: tensor([-0.0851,  0.1652])
# 500 steps | grad: tensor([-0.0747,  0.1366])
# 600 steps | grad: tensor([-0.0569,  0.0781])
# 700 steps | grad: tensor([-0.0972,  0.2250])
# 800 steps | grad: tensor([-0.0301, -0.0278])
# 100 steps | grad: tensor([0.0120])
# 200 steps | grad: tensor([-0.0737])
# 300 steps | grad: tensor([-0.0096])
# 100 steps | grad: tensor([-0.0793,  0.2797])
# 200 steps | grad: tensor([-0.1682,  0.4980])
# 300 steps | grad: tensor([-0.1043,  0.3886])
# 400 steps | grad: tensor([-0.0796,  0.2852])
# 500 steps | grad: tensor([-0.1266,  0.4636])
# 600 steps | grad: tensor([-0.0393,  0.1745])
# 700 steps | grad: tensor([ 0.1034, -0.8244])
# 800 steps | grad: tensor([-0.0993,  0.3795])
# 900 steps | grad: tensor([-0.0184,  0.0736])
# 1000 steps | grad: tensor([-0.0325,  0.1413])
# 1100 steps | grad: tensor([-0.0226,  0.0774])
# 100 steps | grad: tensor([0.2089])
# 200 steps | grad: tensor([0.2464])
# 300 steps | grad: tensor([0.2325])
# 400 steps | grad: tensor([0.1881])
# 500 steps | grad: tensor([0.2100])
# 600 steps | grad: tensor([0.1801])
# 700 steps | grad: tensor([0.1994])
# 800 steps | grad: tensor([0.2206])
# 900 steps | grad: tensor([0.2022])
# 1000 steps | grad: tensor([0.2107])
# 1100 steps | grad: tensor([0.1970])
# 100 steps | grad: tensor([ 0.0030, -0.0503])
# 200 steps | grad: tensor([-0.0148, -0.0696])
# 300 steps | grad: tensor([-0.1226,  0.3320])
# 400 steps | grad: tensor([-0.0541,  0.0953])
# 500 steps | grad: tensor([-0.0975,  0.2496])
# 600 steps | grad: tensor([-0.1757,  0.4888])
# 700 steps | grad: tensor([-0.0918,  0.2298])
# 800 steps | grad: tensor([-0.1117,  0.3418])
# 900 steps | grad: tensor([-0.1711,  0.4992])
# 1000 steps | grad: tensor([ 0.0362, -0.4346])
# 1100 steps | grad: tensor([-0.0579,  0.1377])
# 100 steps | grad: tensor([0.0692])
# 200 steps | grad: tensor([0.0780])
# 300 steps | grad: tensor([0.0041])
# 100 steps | grad: tensor([ 0.2074, -0.7731])
# 200 steps | grad: tensor([ 0.0448, -0.2537])
# 300 steps | grad: tensor([-0.0961,  0.1549])
# 400 steps | grad: tensor([ 0.0365, -0.3444])
# 500 steps | grad: tensor([ 0.0712, -0.4740])
# 600 steps | grad: tensor([ 0.0352, -0.3638])
# 700 steps | grad: tensor([-0.0294, -0.0667])
# 800 steps | grad: tensor([ 0.0285, -0.2918])
# 900 steps | grad: tensor([ 0.0301, -0.3255])
# 1000 steps | grad: tensor([ 0.0072, -0.2170])
# 1100 steps | grad: tensor([-0.0479,  0.0220])
# 100 steps | grad: tensor([0.1449])
# 200 steps | grad: tensor([0.1359])
# 300 steps | grad: tensor([0.1404])
# 400 steps | grad: tensor([0.1730])
# 500 steps | grad: tensor([0.0782])
# 600 steps | grad: tensor([0.1220])
# 700 steps | grad: tensor([0.1658])
# 800 steps | grad: tensor([0.1601])
# 900 steps | grad: tensor([0.1434])
# 1000 steps | grad: tensor([0.1507])
# 100 steps | grad: tensor([-0.0430,  0.2343])
# 200 steps | grad: tensor([-0.1093,  0.3842])
# 300 steps | grad: tensor([ 0.0039, -0.0004])
# 100 steps | grad: tensor([0.1052])
# 200 steps | grad: tensor([0.0050])
# 100 steps | grad: tensor([ 0.0694, -0.0543])
# 200 steps | grad: tensor([-0.0559,  0.2759])
# 300 steps | grad: tensor([-0.0158,  0.1460])
# 400 steps | grad: tensor([-0.0490,  0.2418])
# 500 steps | grad: tensor([0.0100, 0.0134])
# 100 steps | grad: tensor([0.0124])
# 200 steps | grad: tensor([0.0246])
# 300 steps | grad: tensor([0.0346])
# 400 steps | grad: tensor([0.0153])
# 500 steps | grad: tensor([0.0124])
# 600 steps | grad: tensor([0.0297])
# 700 steps | grad: tensor([0.0551])
# 800 steps | grad: tensor([0.0184])
# 900 steps | grad: tensor([0.0339])
# 1000 steps | grad: tensor([0.0478])
# 100 steps | grad: tensor([-0.0280,  0.2047])
# 200 steps | grad: tensor([-0.0572,  0.2581])
# 300 steps | grad: tensor([-0.0008,  0.0416])
# 100 steps | grad: tensor([-0.0166])
# 200 steps | grad: tensor([-0.0338])
# 300 steps | grad: tensor([-0.0460])
# 400 steps | grad: tensor([-0.0654])
# 500 steps | grad: tensor([-0.0943])
# 600 steps | grad: tensor([-0.0720])
# 700 steps | grad: tensor([-0.0536])
# 800 steps | grad: tensor([-0.0812])
# 900 steps | grad: tensor([-0.0254])
# 1000 steps | grad: tensor([-0.0420])
# 1100 steps | grad: tensor([-0.0782])
# 100 steps | grad: tensor([ 0.0822, -0.0334])
# 200 steps | grad: tensor([-0.0638,  0.3154])
# 300 steps | grad: tensor([ 0.0868, -0.4334])
# 400 steps | grad: tensor([-0.0983,  0.4034])
# 500 steps | grad: tensor([-0.1777,  0.5950])
# 600 steps | grad: tensor([-0.0414,  0.2493])
# 700 steps | grad: tensor([-0.0016,  0.0873])
# 800 steps | grad: tensor([-0.0758,  0.3713])
# 900 steps | grad: tensor([ 0.0886, -0.4133])
# 1000 steps | grad: tensor([-0.0584,  0.3036])
# 1100 steps | grad: tensor([-0.0174,  0.1550])
# Logging in: /home/gridsan/stefanou/Regression/ConvergenceTestn100VarLr1e-1/541edaa1-0470-479c-a945-40177d90ac86
# 100 steps | grad: tensor([-0.0413])
# 200 steps | grad: tensor([0.0218])
# 300 steps | grad: tensor([-0.0224])
# 400 steps | grad: tensor([-0.0044])
# 100 steps | grad: tensor([ 0.0703, -0.1461])
# 200 steps | grad: tensor([ 0.0872, -0.4132])
# 300 steps | grad: tensor([ 0.0726, -0.3127])
# 400 steps | grad: tensor([ 0.0712, -0.5732])
# 500 steps | grad: tensor([ 0.0478, -0.2663])
# 600 steps | grad: tensor([ 0.0841, -0.7873])
# 700 steps | grad: tensor([ 0.0204, -0.1683])
# 800 steps | grad: tensor([ 0.0507, -0.3581])
# 900 steps | grad: tensor([ 0.0203, -0.2291])
# 1000 steps | grad: tensor([ 0.0100, -0.1213])
# 1100 steps | grad: tensor([ 0.0386, -0.2728])
# 1200 steps | grad: tensor([ 0.0369, -0.2968])
# 100 steps | grad: tensor([-0.0134])
# 200 steps | grad: tensor([0.0014])
# 100 steps | grad: tensor([ 0.0933, -0.1449])
# 200 steps | grad: tensor([ 0.1581, -0.9372])
# 300 steps | grad: tensor([ 0.1098, -0.6833])
# 400 steps | grad: tensor([ 0.0069, -0.0250])
# 100 steps | grad: tensor([0.0236])
# 200 steps | grad: tensor([0.0070])
# 100 steps | grad: tensor([0.0078, 0.0399])
# 100 steps | grad: tensor([-0.0282])
# 200 steps | grad: tensor([-0.0273])
# 300 steps | grad: tensor([-0.0214])
# 400 steps | grad: tensor([-0.0311])
# 500 steps | grad: tensor([-0.0310])
# 600 steps | grad: tensor([-0.0350])
# 700 steps | grad: tensor([-0.0417])
# 800 steps | grad: tensor([-0.0310])
# 900 steps | grad: tensor([-0.0273])
# 1000 steps | grad: tensor([-0.0320])
# 100 steps | grad: tensor([-0.0514,  0.3154])
# 200 steps | grad: tensor([-0.0015,  0.1607])
# 300 steps | grad: tensor([0.0140, 0.0557])
# 400 steps | grad: tensor([-0.0092,  0.1480])
# 500 steps | grad: tensor([ 0.0201, -0.0179])
# 100 steps | grad: tensor([-0.0626])
# 200 steps | grad: tensor([-0.0750])
# 300 steps | grad: tensor([-0.0827])
# 400 steps | grad: tensor([-0.0487])
# 500 steps | grad: tensor([-0.0294])
# 600 steps | grad: tensor([-0.0580])
# 700 steps | grad: tensor([-0.0549])
# 800 steps | grad: tensor([-0.0675])
# 900 steps | grad: tensor([-0.0746])
# 1000 steps | grad: tensor([-0.0729])
# 1100 steps | grad: tensor([-0.0783])
# 100 steps | grad: tensor([ 0.1185, -0.1510])
# 200 steps | grad: tensor([ 0.0960, -0.2616])
# 300 steps | grad: tensor([ 0.0587, -0.2015])
# 400 steps | grad: tensor([ 0.0578, -0.2610])
# 500 steps | grad: tensor([ 0.1306, -1.0598])
# 600 steps | grad: tensor([ 0.0303, -0.1169])
# 700 steps | grad: tensor([ 0.0601, -0.3578])
# 800 steps | grad: tensor([ 0.0434, -0.1696])
# 900 steps | grad: tensor([ 0.0363, -0.1263])
# 1000 steps | grad: tensor([ 0.0095, -0.0315])
# 100 steps | grad: tensor([0.0103])
# 200 steps | grad: tensor([0.0015])
# 100 steps | grad: tensor([ 0.0932, -0.1561])
# 200 steps | grad: tensor([ 0.0391, -0.0884])
# 300 steps | grad: tensor([ 0.0648, -0.2890])
# 400 steps | grad: tensor([ 0.0035, -0.0172])
# 100 steps | grad: tensor([0.0972])
# 200 steps | grad: tensor([0.0180])
# 300 steps | grad: tensor([0.0890])
# 400 steps | grad: tensor([0.1119])
# 500 steps | grad: tensor([0.0718])
# 600 steps | grad: tensor([0.0616])
# 700 steps | grad: tensor([0.0825])
# 800 steps | grad: tensor([0.0988])
# 900 steps | grad: tensor([0.0763])
# 1000 steps | grad: tensor([0.0599])
# 1100 steps | grad: tensor([0.0936])
# 100 steps | grad: tensor([-0.1811,  0.6559])
# 200 steps | grad: tensor([-0.2021,  0.7554])
# 300 steps | grad: tensor([-0.1405,  0.6737])
# 400 steps | grad: tensor([-0.1172,  0.6435])
# 500 steps | grad: tensor([-0.1793,  0.8001])
# 600 steps | grad: tensor([-0.0575,  0.3904])
# 700 steps | grad: tensor([-0.1125,  0.6246])
# 800 steps | grad: tensor([-0.1442,  0.7284])
# 900 steps | grad: tensor([-0.0837,  0.5157])
# 1000 steps | grad: tensor([-0.1277,  0.7004])
# 1100 steps | grad: tensor([ 0.0375, -0.3945])
# 100 steps | grad: tensor([-0.0955])
# 200 steps | grad: tensor([-0.0988])
# 300 steps | grad: tensor([-0.1122])
# 400 steps | grad: tensor([-0.1434])
# 500 steps | grad: tensor([-0.1241])
# 600 steps | grad: tensor([-0.1240])
# 700 steps | grad: tensor([-0.1125])
# 800 steps | grad: tensor([-0.1227])
# 900 steps | grad: tensor([-0.1217])
# 1000 steps | grad: tensor([-0.1254])
# 1100 steps | grad: tensor([-0.1042])
# 100 steps | grad: tensor([ 0.1898, -0.3504])
# 200 steps | grad: tensor([ 0.1526, -0.4523])
# 300 steps | grad: tensor([ 0.1378, -0.5906])
# 400 steps | grad: tensor([ 0.0830, -0.2766])
# 500 steps | grad: tensor([ 0.0633, -0.2518])
# 600 steps | grad: tensor([ 0.1303, -0.7393])
# 700 steps | grad: tensor([ 0.1154, -0.6560])
# 800 steps | grad: tensor([ 0.1110, -0.5680])
# 900 steps | grad: tensor([ 0.1148, -0.5197])
# 1000 steps | grad: tensor([ 0.1133, -0.6080])
# 1100 steps | grad: tensor([ 0.1192, -0.7090])
# 100 steps | grad: tensor([-0.0595])
# 200 steps | grad: tensor([-0.0202])
# 300 steps | grad: tensor([-0.0393])
# 400 steps | grad: tensor([-0.0586])
# 500 steps | grad: tensor([-0.0474])
# 600 steps | grad: tensor([0.0008])
# 100 steps | grad: tensor([0.0187, 0.1403])
# 200 steps | grad: tensor([-0.0525,  0.3047])
# 300 steps | grad: tensor([0.0136, 0.0402])
# 100 steps | grad: tensor([0.0962])
# 200 steps | grad: tensor([0.0715])
# 300 steps | grad: tensor([0.0181])
# 400 steps | grad: tensor([0.0710])
# 500 steps | grad: tensor([0.0669])
# 600 steps | grad: tensor([0.0642])
# 700 steps | grad: tensor([0.0266])
# 800 steps | grad: tensor([0.0529])
# 900 steps | grad: tensor([0.0526])
# 1000 steps | grad: tensor([0.0766])
# 1100 steps | grad: tensor([0.0551])
# 100 steps | grad: tensor([ 0.3455, -1.2732])
# 200 steps | grad: tensor([ 0.1595, -0.6881])
# 300 steps | grad: tensor([ 0.0579, -0.1316])
# 400 steps | grad: tensor([ 0.1026, -0.4404])
# 500 steps | grad: tensor([ 0.0829, -0.3672])
# 600 steps | grad: tensor([ 0.0834, -0.4002])
# 700 steps | grad: tensor([ 0.0615, -0.2524])
# 800 steps | grad: tensor([ 0.0692, -0.2747])
# 900 steps | grad: tensor([ 0.0473, -0.1838])
# 1000 steps | grad: tensor([ 0.0540, -0.2338])
# 1100 steps | grad: tensor([ 0.0696, -0.3271])
# Logging in: /home/gridsan/stefanou/Regression/ConvergenceTestn100VarLr1e-1/d2024dba-52ee-4d5a-bcf8-2596a0ecf001
# 100 steps | grad: tensor([0.1161])
# 200 steps | grad: tensor([0.0577])
# 300 steps | grad: tensor([0.0431])
# 400 steps | grad: tensor([0.0903])
# 500 steps | grad: tensor([0.0833])
# 600 steps | grad: tensor([0.0868])
# 700 steps | grad: tensor([0.0848])
# 800 steps | grad: tensor([0.0657])
# 900 steps | grad: tensor([0.0869])
# 1000 steps | grad: tensor([0.1062])
# 1100 steps | grad: tensor([0.0457])
# 1200 steps | grad: tensor([0.0463])
# 1300 steps | grad: tensor([0.0681])
# 100 steps | grad: tensor([-0.1180,  0.5025])
# 200 steps | grad: tensor([-0.1465,  0.6078])
# 300 steps | grad: tensor([-0.0015,  0.1190])
# 400 steps | grad: tensor([-0.0001,  0.0828])
# 500 steps | grad: tensor([-0.0209,  0.2224])
# 600 steps | grad: tensor([0.0076, 0.0269])
# 100 steps | grad: tensor([0.1188])
# 200 steps | grad: tensor([0.1030])
# 300 steps | grad: tensor([0.0406])
# 400 steps | grad: tensor([0.0898])
# 500 steps | grad: tensor([0.1197])
# 600 steps | grad: tensor([0.1043])
# 700 steps | grad: tensor([0.1131])
# 800 steps | grad: tensor([0.0453])
# 900 steps | grad: tensor([0.1055])
# 1000 steps | grad: tensor([0.1243])
# 1100 steps | grad: tensor([0.1036])
# 1200 steps | grad: tensor([0.0826])
# 1300 steps | grad: tensor([0.0518])
# 1400 steps | grad: tensor([0.1126])
# 100 steps | grad: tensor([ 0.0989, -0.1851])
# 200 steps | grad: tensor([0.0194, 0.0393])
# 100 steps | grad: tensor([0.0787])
# 200 steps | grad: tensor([0.0512])
# 300 steps | grad: tensor([0.0631])
# 400 steps | grad: tensor([0.0847])
# 500 steps | grad: tensor([0.0812])
# 600 steps | grad: tensor([0.1012])
# 700 steps | grad: tensor([0.0667])
# 800 steps | grad: tensor([0.0625])
# 900 steps | grad: tensor([0.0688])
# 1000 steps | grad: tensor([0.0963])
# 1100 steps | grad: tensor([0.0681])
# 1200 steps | grad: tensor([0.0662])
# 1300 steps | grad: tensor([0.0923])
# 1400 steps | grad: tensor([0.0751])
# 100 steps | grad: tensor([-0.1486,  0.3813])
# 200 steps | grad: tensor([-0.0372,  0.1416])
# 300 steps | grad: tensor([-0.0857,  0.3046])
# 400 steps | grad: tensor([-0.0670,  0.2498])
# 500 steps | grad: tensor([-0.0877,  0.3338])
# 600 steps | grad: tensor([ 0.0316, -0.2071])
# 700 steps | grad: tensor([-0.0361,  0.1578])
# 800 steps | grad: tensor([-0.0647,  0.2461])
# 900 steps | grad: tensor([-0.0156,  0.0457])
# 100 steps | grad: tensor([0.0693])
# 200 steps | grad: tensor([0.0667])
# 300 steps | grad: tensor([0.1004])
# 400 steps | grad: tensor([0.0649])
# 500 steps | grad: tensor([0.0613])
# 600 steps | grad: tensor([0.0958])
# 700 steps | grad: tensor([0.0974])
# 800 steps | grad: tensor([0.0876])
# 900 steps | grad: tensor([0.0908])
# 1000 steps | grad: tensor([0.1011])
# 1100 steps | grad: tensor([0.0737])
# 1200 steps | grad: tensor([0.0857])
# 1300 steps | grad: tensor([0.0889])
# 1400 steps | grad: tensor([0.0248])
# 100 steps | grad: tensor([ 0.1432, -0.2534])
# 200 steps | grad: tensor([ 0.0776, -0.1287])
# 300 steps | grad: tensor([0.0145, 0.1082])
# 400 steps | grad: tensor([-0.0387,  0.2800])
# 500 steps | grad: tensor([0.0222, 0.0128])
# 100 steps | grad: tensor([0.0205])
# 200 steps | grad: tensor([-0.0554])
# 300 steps | grad: tensor([0.0009])
# 100 steps | grad: tensor([ 0.2934, -0.7833])
# 200 steps | grad: tensor([ 0.1360, -0.3752])
# 300 steps | grad: tensor([ 0.0769, -0.1767])
# 400 steps | grad: tensor([ 0.0361, -0.0507])
# 500 steps | grad: tensor([0.0233, 0.0154])
# 100 steps | grad: tensor([0.1271])
# 200 steps | grad: tensor([0.0925])
# 300 steps | grad: tensor([0.0420])
# 400 steps | grad: tensor([0.1025])
# 500 steps | grad: tensor([0.1172])
# 600 steps | grad: tensor([0.0323])
# 700 steps | grad: tensor([0.0766])
# 800 steps | grad: tensor([0.0933])
# 900 steps | grad: tensor([0.0934])
# 1000 steps | grad: tensor([0.0447])
# 1100 steps | grad: tensor([0.0656])
# 1200 steps | grad: tensor([0.0510])
# 1300 steps | grad: tensor([0.0801])
# 1400 steps | grad: tensor([0.0744])
# 100 steps | grad: tensor([ 0.1118, -0.5427])
# 200 steps | grad: tensor([-0.1683,  0.4080])
# 300 steps | grad: tensor([-0.0227, -0.0563])
# 400 steps | grad: tensor([-0.0739,  0.1644])
# 500 steps | grad: tensor([-0.0909,  0.2369])
# 600 steps | grad: tensor([-0.2299,  0.6608])
# 700 steps | grad: tensor([-0.1110,  0.3287])
# 800 steps | grad: tensor([-0.0596,  0.1226])
# 900 steps | grad: tensor([-0.1255,  0.3677])
# 1000 steps | grad: tensor([-0.1530,  0.4546])
# 1100 steps | grad: tensor([-0.0572,  0.0892])
# 1200 steps | grad: tensor([-0.1217,  0.3803])
# 1300 steps | grad: tensor([-0.0502,  0.0680])
# 1400 steps | grad: tensor([-0.0622,  0.1195])
# 100 steps | grad: tensor([0.1936])
# 200 steps | grad: tensor([0.1654])
# 300 steps | grad: tensor([0.1688])
# 400 steps | grad: tensor([0.1087])
# 500 steps | grad: tensor([0.1598])
# 600 steps | grad: tensor([0.1849])
# 700 steps | grad: tensor([0.1792])
# 800 steps | grad: tensor([0.1578])
# 900 steps | grad: tensor([0.1499])
# 1000 steps | grad: tensor([0.1493])
# 1100 steps | grad: tensor([0.1645])
# 1200 steps | grad: tensor([0.1816])
# 1300 steps | grad: tensor([0.1753])
# 1400 steps | grad: tensor([0.1403])
# 100 steps | grad: tensor([ 0.0741, -0.0895])
# 200 steps | grad: tensor([-0.0986,  0.3121])
# 300 steps | grad: tensor([ 0.1034, -0.5381])
# 400 steps | grad: tensor([ 0.0332, -0.1586])
# 500 steps | grad: tensor([-0.0527,  0.1905])
# 600 steps | grad: tensor([ 0.0571, -0.2559])
# 700 steps | grad: tensor([ 0.0583, -0.3397])
# 800 steps | grad: tensor([ 0.0443, -0.2409])
# 900 steps | grad: tensor([-0.0223,  0.1038])
# 1000 steps | grad: tensor([ 0.0319, -0.1410])
# 1100 steps | grad: tensor([-0.0359,  0.1395])
# 1200 steps | grad: tensor([ 0.0654, -0.3458])
# 1300 steps | grad: tensor([-0.0142,  0.0500])
# 1400 steps | grad: tensor([ 0.0131, -0.0439])
# 100 steps | grad: tensor([-0.0028])
# 100 steps | grad: tensor([-0.0965,  0.3198])
# 200 steps | grad: tensor([-0.1281,  0.4520])
# 300 steps | grad: tensor([-0.1168,  0.4371])
# 400 steps | grad: tensor([-0.0792,  0.3301])
# 500 steps | grad: tensor([ 0.0104, -0.2074])
# 600 steps | grad: tensor([-0.0924,  0.3967])
# 700 steps | grad: tensor([-0.0543,  0.2332])
# 800 steps | grad: tensor([-0.0979,  0.4123])
# 900 steps | grad: tensor([-0.1462,  0.5914])
# 1000 steps | grad: tensor([-0.0731,  0.3170])
# 1100 steps | grad: tensor([-0.1410,  0.5569])
# 1200 steps | grad: tensor([-0.0309,  0.0925])
# 1300 steps | grad: tensor([-0.0824,  0.3665])
# 1400 steps | grad: tensor([-0.1039,  0.4361])
# 100 steps | grad: tensor([-0.0206])
# 200 steps | grad: tensor([0.0086])
# 100 steps | grad: tensor([-0.0808,  0.3057])
# 200 steps | grad: tensor([-0.0278,  0.1933])
# 300 steps | grad: tensor([-0.0024,  0.0653])
# 400 steps | grad: tensor([ 0.0478, -0.1891])
# 500 steps | grad: tensor([ 0.0068, -0.0194])
# 100 steps | grad: tensor([-0.0253])
# 200 steps | grad: tensor([0.0261])
# 300 steps | grad: tensor([-0.0378])
# 400 steps | grad: tensor([-0.0074])
# 100 steps | grad: tensor([0.0298, 0.0822])
# 200 steps | grad: tensor([ 0.0794, -0.2489])
# 300 steps | grad: tensor([-0.1033,  0.3804])
# 400 steps | grad: tensor([-0.0098,  0.0724])
# 500 steps | grad: tensor([ 0.0701, -0.3171])
# 600 steps | grad: tensor([ 0.0272, -0.0722])
# 700 steps | grad: tensor([ 0.0483, -0.2174])
# 800 steps | grad: tensor([ 0.0293, -0.1388])
# 900 steps | grad: tensor([ 0.0389, -0.1262])
# 1000 steps | grad: tensor([ 0.0546, -0.2368])
# 1100 steps | grad: tensor([ 0.0800, -0.5268])
# 1200 steps | grad: tensor([-0.0420,  0.2129])
# 1300 steps | grad: tensor([ 0.0285, -0.1085])
# 1400 steps | grad: tensor([ 0.0373, -0.1405])

# %%
# store.close()
reader = CollectionReader(OUT_DIR + EXP)
logs = reader.df(TABLE_NAME)
reader.close()
logs.head()
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 197.08it/s]
#      ols_r2  ols_param_mse  ols_var_l1  known_r2  known_param_mse  known_time  \
# 0 -1.270833       1.062859    0.687570  0.123375         0.102577           1
# 1 -1.187750       1.568495    1.413096  0.060710         0.101731           0
# 2 -1.079875       1.966862    2.101789  0.077132         0.058039           0
# 3 -1.072750       2.417049    2.844415  0.067669         0.037122           4
# 4 -0.978259       2.781888    3.486641  0.054469         0.032072           4
#
#    unknown_r2  unknown_param_mse  unknown_var_l1  unknown_time   alpha  \
# 0    0.002749           0.186224        0.156580             5  0.2437
# 1   -0.055988           0.238673        0.501712             1  0.2957
# 2   -0.346169           0.756217        1.736275             0  0.3235
# 3   -0.076233           0.337221        0.857993             2  0.3430
# 4    0.014100           0.139046        1.101063             4  0.3682
#
#    num_samples  noise_scale                                exp_id
# 0         2437          1.0  541edaa1-0470-479c-a945-40177d90ac86
# 1         2957          2.0  541edaa1-0470-479c-a945-40177d90ac86
# 2         3235          3.0  541edaa1-0470-479c-a945-40177d90ac86
# 3         3430          4.0  541edaa1-0470-479c-a945-40177d90ac86
# 4         3682          5.0  541edaa1-0470-479c-a945-40177d90ac86

# %%
logs

# %%
cleaned_logs = pd.DataFrame(columns=logs.columns)
for var in range(1, 21):
    noise_scale = logs[logs['noise_scale'] == var].reset_index()
    noise_scale.drop(index=noise_scale[['unknown_param_mse', 'unknown_var_mse']].sum(1).idxmax(), inplace=True)
    cleaned_logs = pd.concat([cleaned_logs, noise_scale])
cleaned_logs = cleaned_logs.reset_index()

# %%
cleaned_logs
# Out:
#      level_0    ols_r2  ols_param_mse  ols_var_l1  ols_var_mse  unknown_r2  \
# 0          0  0.052876       0.035191    0.367578     0.135114    0.126953
# 1          1  0.099686       0.050013    0.402627     0.162108    0.216881
# 2          2  0.093766       0.063837    0.390439     0.152443    0.258215
# 3          3 -0.213915       0.123821    0.539218     0.290756    0.219701
# 4          4 -1.826375       0.300547    0.741835     0.550319   -0.621173
# ..       ...       ...            ...         ...          ...         ...
# 509       21 -0.535242       1.068529   12.477976   155.699875   -0.088635
# 510       22 -0.456650       1.023433   11.860272   140.666061   -0.118978
# 511       23 -0.619078       1.294221   12.494238   156.105988   -1.816366
# 512       24 -0.530705       1.116986   12.270186   150.557480   -0.071850
# 513       25 -0.463497       1.063115   11.666103   136.097961    0.018314
#
#      unknown_param_mse  unknown_var_l1  unknown_var_mse unknown_time    alpha  \
# 0             0.011241        0.022865         0.000523           21  0.80450
# 1             0.009505        0.233401         0.054476           10  0.77440
# 2             0.001188        0.042126         0.001775           18  0.75043
# 3             0.005739        0.128202         0.016436            8  0.56800
# 4             0.117608        0.500674         0.250675           18  0.18880
# ..                 ...             ...              ...          ...      ...
# 509           0.232418        9.549336        91.189827           16  0.53480
# 510           0.914294       11.966409       143.194931           14  0.56780
# 511           8.772808        9.987053        99.741226           15  0.50030
# 512           0.543304        6.534191        42.695652           13  0.53700
# 513           0.070980        2.031925         4.128720           11  0.56270
#
#     num_samples  noise_scale                                exp_id  known_r2  \
# 0         80450          1.0  5dfd0daa-d6ef-4643-a3ea-6976acf81378       NaN
# 1          7744          1.0  05ffa43b-a3b7-4be7-9518-65c32f2f7fde  0.239027
# 2         75043          1.0  fb442fce-c577-457b-9d7e-84bc7e718fd0       NaN
# 3          5680          1.0  5e0d3a90-508d-42b8-8084-76ea0233aadc       NaN
# 4          1888          1.0  dbe308eb-4934-4ced-824e-8aa130ad5fc9       NaN
# ..          ...          ...                                   ...       ...
# 509        5348         20.0  20bda2ca-527b-47ef-9629-6c00f3f4e4b1       NaN
# 510       56780         20.0  bdf5151f-6afe-4713-85b6-326ab1bd8cc1       NaN
# 511        5003         20.0  f360b7de-7588-4bae-8307-c56b009c3d7f       NaN
# 512       53700         20.0  a56ca95a-ff5f-4afe-bde3-19f263f49623       NaN
# 513        5627         20.0  2198a86b-a2ec-499f-910e-ce9c9127832f -0.434441
#
#      known_param_mse  known_time  index
# 0                NaN         NaN    0.0
# 1           0.002357         4.0    0.0
# 2                NaN         NaN    0.0
# 3                NaN         NaN    0.0
# 4                NaN         NaN    0.0
# ..               ...         ...    ...
# 509              NaN         NaN   19.0
# 510              NaN         NaN   19.0
# 511              NaN         NaN   19.0
# 512              NaN         NaN   19.0
# 513         0.983125         3.0   19.0
#
# [514 rows x 18 columns]

# %%
logs = logs[logs['noise_scale'] <= 10.0]

# %%
sns.lineplot(data=logs, x='noise_scale', y='ols_param_mse', label='ols')
# sns.lineplot(data=logs, x='noise_scale', y='known_emp_param_mse', label='known emp')
ax = sns.lineplot(data=logs, x='noise_scale', y='known_param_mse', label='known')
ax = sns.lineplot(data=logs, x='noise_scale', y='unknown_param_mse', label='unknown')
ax.set(xlabel='noise_scale', ylabel='L2 Distance to Ground-Truth')
plt.show()

sns.lineplot(data=logs, x='noise_scale', y='ols_var_l1', label='ols')
ax = sns.lineplot(data=logs, x='noise_scale', y='unknown_var_l1', label='unknown')
ax.set(xlabel='noise_scale', ylabel='L1 Distance to Ground-Truth')
# Out:
# [Text(0.5, 0, 'noise_scale'), Text(0, 0.5, 'L1 Distance to Ground-Truth')]

# %%
res.lambda_.inverse()
# Out:
# tensor([[2.9077]], grad_fn=<InverseBackward>)

# %%
ols_var
# Out:
# tensor([[6.6700]])

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 10))
ax = fig.gca(projection='3d')
# data = ch.from_numpy(np.linspace(-3.0, 3.0, 100)).unsqueeze(1).float()

ax.scatter3D(X[indices][:,0], X[indices][:,1], noised[indices], color="green", alpha=.1)
ax.scatter3D(x_trunc[:,0], x_trunc[:,1], y_trunc, color="red", alpha=.75)

ax.view_init(10, -150)

# %%
dist.sample(ch.Size([10000])).norm(dim=-1).max()
# Out:
# tensor(1.6702)

# %%
u = Uniform(-1/d, 1/d)

s = u.sample(ch.Size([10000, d]))

# %%
(x_trunc@w+w0 - y_trunc)
# Out:
# tensor([[-8.0481],
#         [-4.1819],
#         [-3.8256],
#         ...,
#         [ 0.5905],
#         [-2.1130],
#         [-1.7292]])

# %%
unknown_var
# Out:
# tensor([[9.3957]], grad_fn=<MulBackward0>)

# %%
gt.weight, gt.bias
# Out:
# (Parameter containing:
#  tensor([[0.5118]], requires_grad=True),
#  Parameter containing:
#  tensor([[0.5949]], requires_grad=True))

# %%
ols_params
# Out:
# tensor([0.1744, 2.7350])

# %%
ch.abs((x_trunc@w + w0) - y_trunc).mean(0)
# Out:
# tensor([2.5809])

# %%
((X@w + w0) - noised).var(0)
# Out:
# tensor([9.8567])

# %%
(x_trunc@w + w0 - y_trunc).var(0)
# Out:
# tensor([4.2200])

# %%
plt.scatter(X, noised)
plt.scatter(x_trunc, y_trunc)
plt.plot(x_trunc, x_trunc@w + w0, color='r')

# %%
data = Tensor(np.expand_dims(np.linspace(-3, 3), 1))

# %%
x_half, y_half = X[:5000], noised[:5000]

# %%
(x_half@w + w0 - y_half).var(0)
# Out:
# tensor([10.1086])

# %%
(x_trunc@w - y_trunc).var(0)
# Out:
# tensor([4.2200])

# %%
w0
# Out:
# tensor([[0.1702]])
