# %%
import subprocess 
import torch as ch
from torch import Tensor
import torch.linalg as LA
from torch.distributions import Uniform
from torch.distributions.multivariate_normal import MultivariateNormal
import pandas as pd
import numpy as np
import csv
import json
from cox.utils import Parameters
from cox.store import Store
from cox.readers import CollectionReader
import os
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
import math 

import sys 
sys.path.append('../..')
from delphi.stats.linear_regression import TruncatedRegression
from delphi.oracle import Left
from delphi.utils import constants as consts
from delphi.utils.helpers import setup_store_with_metadata

OUT_DIR = '/home/gridsan/stefanou/Regression/NoScale'
TABLE_NAME = 'logs'

# set environment variable so that stores can create output files
os.environ['HDF5_USE_FILE_LOCKING'] = 'FALSE'

# %%
args = Parameters({
    "bias": True,
    "samples": 1000,
    "c": 0,
    "batch_size": 5,
    "lr": 1e-1,
    "var_lr": 1e-2,
    "var_": 1,
    "trials": 3,
    "norm": False,
    "workers": 8,
    "steps": 1000,
    "custom_lr_multiplier": consts.COSINE,
    "x_lower": -10,
    "x_upper": 10,
    "lower": -1,
    "upper": 1,
    "device": "cuda",
    "num_samples": 100,
})
mse_loss = ch.nn.MSELoss()

# %% [markdown]
# I will start by generating the ground-truth for our expriment.

# %%
# distribution for generating feature vectors
d, k = 1, 1
w = Uniform(-1, 1)
m = MultivariateNormal(ch.zeros(d), ch.eye(d)/d)
# m = Uniform(-5, 5)
phi = Left(Tensor([0.0]))

# generate ground truth
gt = ch.nn.Linear(in_features=k, out_features=1)
gt.weight = ch.nn.Parameter(w.sample(ch.Size([k, d])))

# gt.bias = ch.nn.Parameter(ch.ones(1, 1)) if args.bias else None
gt.bias = ch.nn.Parameter(w.sample(ch.Size([1, 1]))) if args.bias else None

print("gt weight: ", gt.weight)
print("gt bias: ", gt.bias)

# create base classifier
with ch.no_grad():
    # generate data
    X = m.sample(ch.Size([args.samples, d])) if isinstance(m, Uniform) else m.sample(ch.Size([args.samples]))

    y = gt(X)

noise_var = Tensor([5.0])[...,None]
# remove synthetic data from the computation graph
with ch.no_grad():
    # add noise to ground-truth pedictions
    noised = y + ch.sqrt(noise_var) * ch.randn(X.size(0), 1)
    # truncate based off of the standardized data
    indices = phi(noised).nonzero(as_tuple=False).flatten()
    y_trunc, x_trunc = noised[indices], X[indices]
    alpha = Tensor([y_trunc.size(0) / args.samples])
    print("alpha: ", alpha)
    
# ground-truth OLS
gt_ols = LinearRegression()
gt_ols.fit(X, noised)
print("gt ols coef: ", gt_ols.coef_)
print("gt ols intercept: ", gt_ols.intercept_)

trunc_ols = LinearRegression()
trunc_ols.fit(x_trunc, y_trunc)
trunc_ols_pred = trunc_ols.predict(x_trunc)
print("trunc ols coef: ", trunc_ols.coef_)
print("trunc ols intercept: ", trunc_ols.intercept_)

# data for plotting regressions
unnorm_data = np.linspace(-5, 5, 100).reshape(100, 1)
norm_data = np.linspace(-1, 1, 100).reshape(100, 1)

ax = plt.subplot(1, 1, 1)
plt.scatter(X, noised)
plt.scatter(x_trunc, y_trunc)
plt.plot(unnorm_data, gt_ols.predict(unnorm_data), color='green', label='gt ols')
plt.plot(unnorm_data, trunc_ols.predict(unnorm_data), color='red', label='trunc ols')
plt.legend()
plt.title("Empirical and Ground Truth Dataset and Model")
ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# gt weight:  Parameter containing:
# tensor([[-0.5074]], requires_grad=True)
# gt bias:  Parameter containing:
# tensor([[0.7082]], requires_grad=True)
# alpha:  tensor([0.6330])
# gt ols coef:  [[-0.57287836]]
# gt ols intercept:  [0.6346839]
# trunc ols coef:  [[-0.28610468]]
# trunc ols intercept:  [2.0305169]
# Text(0, 0.5, 'y')

# %% [markdown]
# Now, we want to standardize our truncated dataset, so that our empirical estimates are located on the l2 ball. First we will divide all of our covariate features by $B\sqrt{k}$, so that all of our covariate features $||x_{i}||_{2}^{2} \leq 1$, and reside on the $\ell_{2}$ ball. This way the norm of $w$ will be multiplied by $B\sqrt{k}$.

# %%
max_x_trunc_norm = LA.norm(x_trunc, dim=-1, ord=float('inf')).max()
print("max truncated x norm", max_x_trunc_norm)

beta = max_x_trunc_norm*math.sqrt(X.size(1))
print("beta: ", beta)

x_trunc_norm = x_trunc / beta
print("x max l2: ", x_trunc_norm.norm(dim=-1).max())
# Out:
# max truncated x norm tensor(3.5058)
# beta:  tensor(3.5058)
# x max l2:  tensor(1.)

# %% [markdown]
# We now observe that the norm of the truncated x covariates is bounded by 1. So, now we will standardze our dependent variable so that it's ground-truth takes the form of the linear regression latent variable model with noise variance of 1. First, let's calculate the predicted values from our naive ols regression on teh truncated data.

# %% [markdown]
# First, we will standardize our data for the case where we assume that the empirical noise variance is the underlying noise variance of the ground truth regression.

# %%
emp_noise_var = (y_trunc - trunc_ols_pred).var(0)
print("emp noise var: ", emp_noise_var)

emp_stand_y_trunc = y_trunc / ch.sqrt(emp_noise_var)
trunc_noise_var = (emp_stand_y_trunc - (trunc_ols_pred / ch.sqrt(emp_noise_var))).var(0)
print("trunc reg noise var: ", trunc_noise_var)

new_X, emp_stand_noised = X / beta, noised / ch.sqrt(emp_noise_var)

gt_emp_stand = LinearRegression()
gt_emp_stand.fit(new_X, emp_stand_noised)

trunc_emp_stand_ols = LinearRegression()
trunc_emp_stand_ols.fit(x_trunc_norm, emp_stand_y_trunc)

ax = plt.subplot(1, 1, 1)
plt.scatter(new_X, emp_stand_noised, label='entire dataset', alpha=.75)
plt.scatter(x_trunc_norm, emp_stand_y_trunc, label='truncated dataset', alpha=.75)
plt.plot(norm_data, gt_emp_stand.predict(norm_data), color='green', label='gt ols')
plt.plot(norm_data, trunc_emp_stand_ols.predict(norm_data), color='red', label='trunc ols')
plt.legend()
plt.title('Y Scaled by Empirical Noise Variance')
ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# emp noise var:  tensor([2.1834])
# trunc reg noise var:  tensor([1.])
# Text(0, 0.5, 'y')

# %% [markdown]
# First, we will standardize our data for the case where we assume that wee know the underlying ground-truth noise variance.

# %%
stand_noised, stand_y_trunc = noised / ch.sqrt(noise_var), y_trunc / ch.sqrt(noise_var)

gt_stand = LinearRegression()
gt_stand.fit(new_X, stand_noised)

trunc_stand_ols = LinearRegression()
trunc_stand_ols.fit(x_trunc_norm, stand_y_trunc)

ax = plt.subplot(1, 1, 1)
plt.scatter(new_X, stand_noised, label='entire dataset', alpha=.75)
plt.scatter(x_trunc_norm, stand_y_trunc, label='truncated dataset', alpha=.75)
plt.plot(norm_data, gt_stand.predict(norm_data), color='green', label='gt ols')
plt.plot(norm_data, trunc_stand_ols.predict(norm_data), color='red', label='trunc ols')
plt.legend()
plt.title("Y Scaled by Ground-Truth Noise Variance")
ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# Truncated Regression with Known Empirical Variance

# %%
trunc_reg = TruncatedRegression(phi=phi, alpha=alpha, args=args, bias=True, var=ch.ones(1))
known_emp_res = trunc_reg.fit(x_trunc_norm, emp_stand_y_trunc)
known_emp_w_unnorm, known_emp_bias_unnorm = (known_emp_res.weight * ch.sqrt(emp_noise_var)) / beta, (known_emp_res.bias * ch.sqrt(emp_noise_var))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=44.0), HTML(value='')))
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0016]], requires_grad=True), Parameter containing:
# tensor([1.0935], requires_grad=True)], 'lr': 0.09949107209404665, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.9823]], requires_grad=True), Parameter containing:
# tensor([1.0422], requires_grad=True)], 'lr': 0.09797464868072488, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.9729]], requires_grad=True), Parameter containing:
# tensor([1.0265], requires_grad=True)], 'lr': 0.09548159976772592, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.9581]], requires_grad=True), Parameter containing:
# tensor([0.9988], requires_grad=True)], 'lr': 0.09206267664155907, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.9836]], requires_grad=True), Parameter containing:
# tensor([1.0546], requires_grad=True)], 'lr': 0.08778747871771292, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.9799]], requires_grad=True), Parameter containing:
# tensor([1.0446], requires_grad=True)], 'lr': 0.08274303669726427, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.9839]], requires_grad=True), Parameter containing:
# tensor([1.0205], requires_grad=True)], 'lr': 0.07703204087277989, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0009]], requires_grad=True), Parameter containing:
# tensor([1.0314], requires_grad=True)], 'lr': 0.07077075065009433, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.9953]], requires_grad=True), Parameter containing:
# tensor([1.0044], requires_grad=True)], 'lr': 0.06408662784207149, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.9970]], requires_grad=True), Parameter containing:
# tensor([1.0064], requires_grad=True)], 'lr': 0.05711574191366425, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.9868]], requires_grad=True), Parameter containing:
# tensor([0.9847], requires_grad=True)], 'lr': 0.05000000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0008]], requires_grad=True), Parameter containing:
# tensor([0.9937], requires_grad=True)], 'lr': 0.04288425808633575, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.9963]], requires_grad=True), Parameter containing:
# tensor([0.9974], requires_grad=True)], 'lr': 0.035913372157928516, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.9996]], requires_grad=True), Parameter containing:
# tensor([0.9898], requires_grad=True)], 'lr': 0.029229249349905687, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0002]], requires_grad=True), Parameter containing:
# tensor([0.9856], requires_grad=True)], 'lr': 0.02296795912722014, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.9981]], requires_grad=True), Parameter containing:
# tensor([0.9794], requires_grad=True)], 'lr': 0.017256963302735753, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0032]], requires_grad=True), Parameter containing:
# tensor([0.9860], requires_grad=True)], 'lr': 0.012212521282287095, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0006]], requires_grad=True), Parameter containing:
# tensor([0.9787], requires_grad=True)], 'lr': 0.007937323358440947, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0005]], requires_grad=True), Parameter containing:
# tensor([0.9791], requires_grad=True)], 'lr': 0.004518400232274089, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0029]], requires_grad=True), Parameter containing:
# tensor([0.9814], requires_grad=True)], 'lr': 0.002025351319275132, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0027]], requires_grad=True), Parameter containing:
# tensor([0.9808], requires_grad=True)], 'lr': 0.0005089279059533658, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0027]], requires_grad=True), Parameter containing:
# tensor([0.9808], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0027]], requires_grad=True), Parameter containing:
# tensor([0.9808], requires_grad=True)], 'lr': 0.0005089279059533658, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0027]], requires_grad=True), Parameter containing:
# tensor([0.9807], requires_grad=True)], 'lr': 0.002025351319275148, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0028]], requires_grad=True), Parameter containing:
# tensor([0.9802], requires_grad=True)], 'lr': 0.004518400232274132, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0022]], requires_grad=True), Parameter containing:
# tensor([0.9792], requires_grad=True)], 'lr': 0.007937323358441025, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0043]], requires_grad=True), Parameter containing:
# tensor([0.9786], requires_grad=True)], 'lr': 0.012212521282287213, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0076]], requires_grad=True), Parameter containing:
# tensor([0.9797], requires_grad=True)], 'lr': 0.017256963302735927, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0056]], requires_grad=True), Parameter containing:
# tensor([0.9742], requires_grad=True)], 'lr': 0.022967959127220376, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.9983]], requires_grad=True), Parameter containing:
# tensor([0.9661], requires_grad=True)], 'lr': 0.029229249349905954, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.9971]], requires_grad=True), Parameter containing:
# tensor([0.9589], requires_grad=True)], 'lr': 0.0359133721579289, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0075]], requires_grad=True), Parameter containing:
# tensor([0.9530], requires_grad=True)], 'lr': 0.0428842580863362, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0133]], requires_grad=True), Parameter containing:
# tensor([0.9768], requires_grad=True)], 'lr': 0.05000000000000052, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0393]], requires_grad=True), Parameter containing:
# tensor([1.0079], requires_grad=True)], 'lr': 0.05711574191366485, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0467]], requires_grad=True), Parameter containing:
# tensor([0.9828], requires_grad=True)], 'lr': 0.06408662784207216, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0483]], requires_grad=True), Parameter containing:
# tensor([0.9745], requires_grad=True)], 'lr': 0.07077075065009507, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0519]], requires_grad=True), Parameter containing:
# tensor([0.9658], requires_grad=True)], 'lr': 0.07703204087278072, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0508]], requires_grad=True), Parameter containing:
# tensor([0.9475], requires_grad=True)], 'lr': 0.08274303669726511, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0370]], requires_grad=True), Parameter containing:
# tensor([0.8959], requires_grad=True)], 'lr': 0.08778747871771382, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0528]], requires_grad=True), Parameter containing:
# tensor([0.9166], requires_grad=True)], 'lr': 0.09206267664156005, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0769]], requires_grad=True), Parameter containing:
# tensor([0.9605], requires_grad=True)], 'lr': 0.09548159976772692, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0963]], requires_grad=True), Parameter containing:
# tensor([0.9697], requires_grad=True)], 'lr': 0.09797464868072593, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0645]], requires_grad=True), Parameter containing:
# tensor([0.9528], requires_grad=True)], 'lr': 0.09949107209404771, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0804]], requires_grad=True), Parameter containing:
# tensor([0.8690], requires_grad=True)], 'lr': 0.10000000000000107, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# HBox(children=(FloatProgress(value=0.0, max=44.0), HTML(value='')))
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0712]], requires_grad=True), Parameter containing:
# tensor([0.8528], requires_grad=True)], 'lr': 0.09949107209404771, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0625]], requires_grad=True), Parameter containing:
# tensor([0.8198], requires_grad=True)], 'lr': 0.09797464868072593, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0672]], requires_grad=True), Parameter containing:
# tensor([0.8180], requires_grad=True)], 'lr': 0.09548159976772694, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0699]], requires_grad=True), Parameter containing:
# tensor([0.8071], requires_grad=True)], 'lr': 0.09206267664156007, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0625]], requires_grad=True), Parameter containing:
# tensor([0.8100], requires_grad=True)], 'lr': 0.08778747871771388, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0485]], requires_grad=True), Parameter containing:
# tensor([0.7643], requires_grad=True)], 'lr': 0.08274303669726514, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0711]], requires_grad=True), Parameter containing:
# tensor([0.7582], requires_grad=True)], 'lr': 0.07703204087278075, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0736]], requires_grad=True), Parameter containing:
# tensor([0.7344], requires_grad=True)], 'lr': 0.07077075065009508, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0742]], requires_grad=True), Parameter containing:
# tensor([0.7342], requires_grad=True)], 'lr': 0.06408662784207217, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0750]], requires_grad=True), Parameter containing:
# tensor([0.7210], requires_grad=True)], 'lr': 0.05711574191366487, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0827]], requires_grad=True), Parameter containing:
# tensor([0.7308], requires_grad=True)], 'lr': 0.0500000000000005, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0876]], requires_grad=True), Parameter containing:
# tensor([0.7522], requires_grad=True)], 'lr': 0.04288425808633622, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.0981]], requires_grad=True), Parameter containing:
# tensor([0.7608], requires_grad=True)], 'lr': 0.03591337215792892, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.1032]], requires_grad=True), Parameter containing:
# tensor([0.7703], requires_grad=True)], 'lr': 0.029229249349905975, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.1076]], requires_grad=True), Parameter containing:
# tensor([0.7725], requires_grad=True)], 'lr': 0.022967959127220397, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.1165]], requires_grad=True), Parameter containing:
# tensor([0.7879], requires_grad=True)], 'lr': 0.017256963302735993, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.1077]], requires_grad=True), Parameter containing:
# tensor([0.7771], requires_grad=True)], 'lr': 0.012212521282287246, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.1092]], requires_grad=True), Parameter containing:
# tensor([0.7759], requires_grad=True)], 'lr': 0.007937323358441025, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.1098]], requires_grad=True), Parameter containing:
# tensor([0.7752], requires_grad=True)], 'lr': 0.004518400232274115, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.1084]], requires_grad=True), Parameter containing:
# tensor([0.7723], requires_grad=True)], 'lr': 0.002025351319275153, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.1086]], requires_grad=True), Parameter containing:
# tensor([0.7734], requires_grad=True)], 'lr': 0.0005089279059533768, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.1086]], requires_grad=True), Parameter containing:
# tensor([0.7733], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.1086]], requires_grad=True), Parameter containing:
# tensor([0.7733], requires_grad=True)], 'lr': 0.0005089279059533658, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.1085]], requires_grad=True), Parameter containing:
# tensor([0.7733], requires_grad=True)], 'lr': 0.0020253513192751644, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.1089]], requires_grad=True), Parameter containing:
# tensor([0.7735], requires_grad=True)], 'lr': 0.0045184002322741865, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.1100]], requires_grad=True), Parameter containing:
# tensor([0.7756], requires_grad=True)], 'lr': 0.007937323358441094, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.1101]], requires_grad=True), Parameter containing:
# tensor([0.7770], requires_grad=True)], 'lr': 0.012212521282287348, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.1172]], requires_grad=True), Parameter containing:
# tensor([0.7832], requires_grad=True)], 'lr': 0.01725696330273608, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.1201]], requires_grad=True), Parameter containing:
# tensor([0.7865], requires_grad=True)], 'lr': 0.02296795912722061, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.1210]], requires_grad=True), Parameter containing:
# tensor([0.7893], requires_grad=True)], 'lr': 0.02922924934990634, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.1250]], requires_grad=True), Parameter containing:
# tensor([0.7840], requires_grad=True)], 'lr': 0.03591337215792927, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.1197]], requires_grad=True), Parameter containing:
# tensor([0.7708], requires_grad=True)], 'lr': 0.0428842580863366, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.1189]], requires_grad=True), Parameter containing:
# tensor([0.7873], requires_grad=True)], 'lr': 0.05000000000000105, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.1347]], requires_grad=True), Parameter containing:
# tensor([0.7917], requires_grad=True)], 'lr': 0.05711574191366541, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.1390]], requires_grad=True), Parameter containing:
# tensor([0.7880], requires_grad=True)], 'lr': 0.06408662784207284, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.1633]], requires_grad=True), Parameter containing:
# tensor([0.8184], requires_grad=True)], 'lr': 0.07077075065009586, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.1586]], requires_grad=True), Parameter containing:
# tensor([0.7972], requires_grad=True)], 'lr': 0.07703204087278151, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.1615]], requires_grad=True), Parameter containing:
# tensor([0.8119], requires_grad=True)], 'lr': 0.08274303669726599, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.1688]], requires_grad=True), Parameter containing:
# tensor([0.8021], requires_grad=True)], 'lr': 0.08778747871771483, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.1704]], requires_grad=True), Parameter containing:
# tensor([0.7943], requires_grad=True)], 'lr': 0.09206267664156104, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.1841]], requires_grad=True), Parameter containing:
# tensor([0.7988], requires_grad=True)], 'lr': 0.09548159976772796, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.1774]], requires_grad=True), Parameter containing:
# tensor([0.8106], requires_grad=True)], 'lr': 0.09797464868072697, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2249]], requires_grad=True), Parameter containing:
# tensor([0.8618], requires_grad=True)], 'lr': 0.09949107209404877, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2867]], requires_grad=True), Parameter containing:
# tensor([0.9382], requires_grad=True)], 'lr': 0.10000000000000216, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# HBox(children=(FloatProgress(value=0.0, max=44.0), HTML(value='')))
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2693]], requires_grad=True), Parameter containing:
# tensor([0.8995], requires_grad=True)], 'lr': 0.09949107209404878, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2490]], requires_grad=True), Parameter containing:
# tensor([0.8588], requires_grad=True)], 'lr': 0.09797464868072699, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2782]], requires_grad=True), Parameter containing:
# tensor([0.8997], requires_grad=True)], 'lr': 0.09548159976772798, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2878]], requires_grad=True), Parameter containing:
# tensor([0.8813], requires_grad=True)], 'lr': 0.09206267664156106, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2832]], requires_grad=True), Parameter containing:
# tensor([0.8827], requires_grad=True)], 'lr': 0.08778747871771486, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2619]], requires_grad=True), Parameter containing:
# tensor([0.8451], requires_grad=True)], 'lr': 0.08274303669726599, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2584]], requires_grad=True), Parameter containing:
# tensor([0.8268], requires_grad=True)], 'lr': 0.07703204087278154, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2868]], requires_grad=True), Parameter containing:
# tensor([0.8398], requires_grad=True)], 'lr': 0.07077075065009589, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2916]], requires_grad=True), Parameter containing:
# tensor([0.8377], requires_grad=True)], 'lr': 0.06408662784207288, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2773]], requires_grad=True), Parameter containing:
# tensor([0.8518], requires_grad=True)], 'lr': 0.05711574191366554, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2847]], requires_grad=True), Parameter containing:
# tensor([0.8506], requires_grad=True)], 'lr': 0.050000000000001, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2876]], requires_grad=True), Parameter containing:
# tensor([0.8562], requires_grad=True)], 'lr': 0.04288425808633664, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2855]], requires_grad=True), Parameter containing:
# tensor([0.8488], requires_grad=True)], 'lr': 0.03591337215792931, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2725]], requires_grad=True), Parameter containing:
# tensor([0.8223], requires_grad=True)], 'lr': 0.029229249349906374, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2710]], requires_grad=True), Parameter containing:
# tensor([0.8201], requires_grad=True)], 'lr': 0.022967959127220647, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2794]], requires_grad=True), Parameter containing:
# tensor([0.8308], requires_grad=True)], 'lr': 0.017256963302736114, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2856]], requires_grad=True), Parameter containing:
# tensor([0.8366], requires_grad=True)], 'lr': 0.01221252128228732, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2824]], requires_grad=True), Parameter containing:
# tensor([0.8369], requires_grad=True)], 'lr': 0.007937323358441117, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2817]], requires_grad=True), Parameter containing:
# tensor([0.8351], requires_grad=True)], 'lr': 0.0045184002322741995, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2823]], requires_grad=True), Parameter containing:
# tensor([0.8355], requires_grad=True)], 'lr': 0.002025351319275179, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2822]], requires_grad=True), Parameter containing:
# tensor([0.8352], requires_grad=True)], 'lr': 0.0005089279059533818, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2822]], requires_grad=True), Parameter containing:
# tensor([0.8352], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2822]], requires_grad=True), Parameter containing:
# tensor([0.8352], requires_grad=True)], 'lr': 0.0005089279059533658, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2823]], requires_grad=True), Parameter containing:
# tensor([0.8353], requires_grad=True)], 'lr': 0.0020253513192751206, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2820]], requires_grad=True), Parameter containing:
# tensor([0.8350], requires_grad=True)], 'lr': 0.004518400232274045, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2818]], requires_grad=True), Parameter containing:
# tensor([0.8338], requires_grad=True)], 'lr': 0.007937323358440919, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2832]], requires_grad=True), Parameter containing:
# tensor([0.8355], requires_grad=True)], 'lr': 0.012212521282287083, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2813]], requires_grad=True), Parameter containing:
# tensor([0.8373], requires_grad=True)], 'lr': 0.017256963302735778, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2813]], requires_grad=True), Parameter containing:
# tensor([0.8414], requires_grad=True)], 'lr': 0.02296795912722004, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2778]], requires_grad=True), Parameter containing:
# tensor([0.8228], requires_grad=True)], 'lr': 0.029229249349905624, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2936]], requires_grad=True), Parameter containing:
# tensor([0.8408], requires_grad=True)], 'lr': 0.0359133721579285, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2812]], requires_grad=True), Parameter containing:
# tensor([0.8188], requires_grad=True)], 'lr': 0.04288425808633559, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2826]], requires_grad=True), Parameter containing:
# tensor([0.8207], requires_grad=True)], 'lr': 0.050000000000000065, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2715]], requires_grad=True), Parameter containing:
# tensor([0.8058], requires_grad=True)], 'lr': 0.057115741913664184, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2753]], requires_grad=True), Parameter containing:
# tensor([0.8213], requires_grad=True)], 'lr': 0.06408662784207145, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2746]], requires_grad=True), Parameter containing:
# tensor([0.8012], requires_grad=True)], 'lr': 0.07077075065009432, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2806]], requires_grad=True), Parameter containing:
# tensor([0.7775], requires_grad=True)], 'lr': 0.07703204087277976, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2875]], requires_grad=True), Parameter containing:
# tensor([0.7644], requires_grad=True)], 'lr': 0.0827430366972643, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2648]], requires_grad=True), Parameter containing:
# tensor([0.7431], requires_grad=True)], 'lr': 0.08778747871771286, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2595]], requires_grad=True), Parameter containing:
# tensor([0.7193], requires_grad=True)], 'lr': 0.09206267664155904, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.2887]], requires_grad=True), Parameter containing:
# tensor([0.7402], requires_grad=True)], 'lr': 0.09548159976772591, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3091]], requires_grad=True), Parameter containing:
# tensor([0.7577], requires_grad=True)], 'lr': 0.09797464868072482, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3178]], requires_grad=True), Parameter containing:
# tensor([0.7768], requires_grad=True)], 'lr': 0.09949107209404665, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3514]], requires_grad=True), Parameter containing:
# tensor([0.8079], requires_grad=True)], 'lr': 0.1, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# HBox(children=(FloatProgress(value=0.0, max=44.0), HTML(value='')))
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3696]], requires_grad=True), Parameter containing:
# tensor([0.8235], requires_grad=True)], 'lr': 0.09949107209404665, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3822]], requires_grad=True), Parameter containing:
# tensor([0.8305], requires_grad=True)], 'lr': 0.09797464868072492, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3640]], requires_grad=True), Parameter containing:
# tensor([0.7977], requires_grad=True)], 'lr': 0.09548159976772597, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3582]], requires_grad=True), Parameter containing:
# tensor([0.7603], requires_grad=True)], 'lr': 0.09206267664155911, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.4177]], requires_grad=True), Parameter containing:
# tensor([0.8310], requires_grad=True)], 'lr': 0.08778747871771295, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3922]], requires_grad=True), Parameter containing:
# tensor([0.8176], requires_grad=True)], 'lr': 0.08274303669726425, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3492]], requires_grad=True), Parameter containing:
# tensor([0.7513], requires_grad=True)], 'lr': 0.07703204087277998, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3319]], requires_grad=True), Parameter containing:
# tensor([0.7515], requires_grad=True)], 'lr': 0.0707707506500944, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3293]], requires_grad=True), Parameter containing:
# tensor([0.7391], requires_grad=True)], 'lr': 0.06408662784207153, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3355]], requires_grad=True), Parameter containing:
# tensor([0.7482], requires_grad=True)], 'lr': 0.057115741913664274, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3548]], requires_grad=True), Parameter containing:
# tensor([0.7882], requires_grad=True)], 'lr': 0.04999999999999997, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3466]], requires_grad=True), Parameter containing:
# tensor([0.7632], requires_grad=True)], 'lr': 0.04288425808633585, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3386]], requires_grad=True), Parameter containing:
# tensor([0.7656], requires_grad=True)], 'lr': 0.03591337215792857, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3391]], requires_grad=True), Parameter containing:
# tensor([0.7579], requires_grad=True)], 'lr': 0.029229249349905694, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3331]], requires_grad=True), Parameter containing:
# tensor([0.7423], requires_grad=True)], 'lr': 0.022967959127220102, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3284]], requires_grad=True), Parameter containing:
# tensor([0.7359], requires_grad=True)], 'lr': 0.0172569633027357, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3249]], requires_grad=True), Parameter containing:
# tensor([0.7301], requires_grad=True)], 'lr': 0.012212521282287135, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3253]], requires_grad=True), Parameter containing:
# tensor([0.7280], requires_grad=True)], 'lr': 0.007937323358440959, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3264]], requires_grad=True), Parameter containing:
# tensor([0.7306], requires_grad=True)], 'lr': 0.004518400232274151, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3277]], requires_grad=True), Parameter containing:
# tensor([0.7314], requires_grad=True)], 'lr': 0.0020253513192751652, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3275]], requires_grad=True), Parameter containing:
# tensor([0.7306], requires_grad=True)], 'lr': 0.000508927905953377, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3274]], requires_grad=True), Parameter containing:
# tensor([0.7306], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3274]], requires_grad=True), Parameter containing:
# tensor([0.7306], requires_grad=True)], 'lr': 0.0005089279059533658, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3276]], requires_grad=True), Parameter containing:
# tensor([0.7309], requires_grad=True)], 'lr': 0.002025351319275115, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3271]], requires_grad=True), Parameter containing:
# tensor([0.7307], requires_grad=True)], 'lr': 0.004518400232274089, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3272]], requires_grad=True), Parameter containing:
# tensor([0.7301], requires_grad=True)], 'lr': 0.007937323358440995, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3292]], requires_grad=True), Parameter containing:
# tensor([0.7337], requires_grad=True)], 'lr': 0.012212521282287211, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3312]], requires_grad=True), Parameter containing:
# tensor([0.7339], requires_grad=True)], 'lr': 0.01725696330273595, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3322]], requires_grad=True), Parameter containing:
# tensor([0.7366], requires_grad=True)], 'lr': 0.022967959127220276, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3389]], requires_grad=True), Parameter containing:
# tensor([0.7415], requires_grad=True)], 'lr': 0.02922924934990593, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3482]], requires_grad=True), Parameter containing:
# tensor([0.7560], requires_grad=True)], 'lr': 0.03591337215792888, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3550]], requires_grad=True), Parameter containing:
# tensor([0.7576], requires_grad=True)], 'lr': 0.042884258086336044, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3617]], requires_grad=True), Parameter containing:
# tensor([0.7596], requires_grad=True)], 'lr': 0.05000000000000042, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3551]], requires_grad=True), Parameter containing:
# tensor([0.7417], requires_grad=True)], 'lr': 0.057115741913664975, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3580]], requires_grad=True), Parameter containing:
# tensor([0.7352], requires_grad=True)], 'lr': 0.06408662784207231, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3603]], requires_grad=True), Parameter containing:
# tensor([0.7363], requires_grad=True)], 'lr': 0.0707707506500951, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3593]], requires_grad=True), Parameter containing:
# tensor([0.7238], requires_grad=True)], 'lr': 0.07703204087278076, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3438]], requires_grad=True), Parameter containing:
# tensor([0.7127], requires_grad=True)], 'lr': 0.08274303669726508, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3349]], requires_grad=True), Parameter containing:
# tensor([0.7029], requires_grad=True)], 'lr': 0.08778747871771382, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3432]], requires_grad=True), Parameter containing:
# tensor([0.7181], requires_grad=True)], 'lr': 0.09206267664156005, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3603]], requires_grad=True), Parameter containing:
# tensor([0.7072], requires_grad=True)], 'lr': 0.0954815997677269, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3725]], requires_grad=True), Parameter containing:
# tensor([0.7054], requires_grad=True)], 'lr': 0.0979746486807259, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3720]], requires_grad=True), Parameter containing:
# tensor([0.7187], requires_grad=True)], 'lr': 0.0994910720940477, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3686]], requires_grad=True), Parameter containing:
# tensor([0.6920], requires_grad=True)], 'lr': 0.10000000000000109, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# HBox(children=(FloatProgress(value=0.0, max=44.0), HTML(value='')))
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3474]], requires_grad=True), Parameter containing:
# tensor([0.6374], requires_grad=True)], 'lr': 0.09949107209404773, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3233]], requires_grad=True), Parameter containing:
# tensor([0.5986], requires_grad=True)], 'lr': 0.09797464868072593, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3284]], requires_grad=True), Parameter containing:
# tensor([0.5947], requires_grad=True)], 'lr': 0.09548159976772692, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3518]], requires_grad=True), Parameter containing:
# tensor([0.6003], requires_grad=True)], 'lr': 0.09206267664156009, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3390]], requires_grad=True), Parameter containing:
# tensor([0.5666], requires_grad=True)], 'lr': 0.08778747871771388, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.3696]], requires_grad=True), Parameter containing:
# ...
# tensor([0.6110], requires_grad=True)], 'lr': 0.017256963302737027, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.5897]], requires_grad=True), Parameter containing:
# tensor([0.6099], requires_grad=True)], 'lr': 0.022967959127221566, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.5871]], requires_grad=True), Parameter containing:
# tensor([0.6031], requires_grad=True)], 'lr': 0.029229249349907935, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.5833]], requires_grad=True), Parameter containing:
# tensor([0.5945], requires_grad=True)], 'lr': 0.03591337215793097, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.5950]], requires_grad=True), Parameter containing:
# tensor([0.6054], requires_grad=True)], 'lr': 0.042884258086338764, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.5857]], requires_grad=True), Parameter containing:
# tensor([0.6027], requires_grad=True)], 'lr': 0.05000000000000395, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.5883]], requires_grad=True), Parameter containing:
# tensor([0.5953], requires_grad=True)], 'lr': 0.057115741913668444, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.5959]], requires_grad=True), Parameter containing:
# tensor([0.6051], requires_grad=True)], 'lr': 0.06408662784207658, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.5812]], requires_grad=True), Parameter containing:
# tensor([0.5974], requires_grad=True)], 'lr': 0.07077075065009963, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.5749]], requires_grad=True), Parameter containing:
# tensor([0.5813], requires_grad=True)], 'lr': 0.0770320408727857, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.5785]], requires_grad=True), Parameter containing:
# tensor([0.5809], requires_grad=True)], 'lr': 0.08274303669727029, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.5770]], requires_grad=True), Parameter containing:
# tensor([0.5667], requires_grad=True)], 'lr': 0.08778747871771962, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6177]], requires_grad=True), Parameter containing:
# tensor([0.6333], requires_grad=True)], 'lr': 0.09206267664156592, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6164]], requires_grad=True), Parameter containing:
# tensor([0.6377], requires_grad=True)], 'lr': 0.09548159976773309, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6220]], requires_grad=True), Parameter containing:
# tensor([0.6335], requires_grad=True)], 'lr': 0.09797464868073227, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6246]], requires_grad=True), Parameter containing:
# tensor([0.6157], requires_grad=True)], 'lr': 0.0994910720940542, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6406]], requires_grad=True), Parameter containing:
# tensor([0.6143], requires_grad=True)], 'lr': 0.10000000000000761, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# HBox(children=(FloatProgress(value=0.0, max=44.0), HTML(value='')))
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6454]], requires_grad=True), Parameter containing:
# tensor([0.6216], requires_grad=True)], 'lr': 0.09949107209405421, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6307]], requires_grad=True), Parameter containing:
# tensor([0.5963], requires_grad=True)], 'lr': 0.09797464868073233, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6284]], requires_grad=True), Parameter containing:
# tensor([0.6105], requires_grad=True)], 'lr': 0.09548159976773332, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6304]], requires_grad=True), Parameter containing:
# tensor([0.6037], requires_grad=True)], 'lr': 0.09206267664156603, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6247]], requires_grad=True), Parameter containing:
# tensor([0.5991], requires_grad=True)], 'lr': 0.08778747871771976, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6574]], requires_grad=True), Parameter containing:
# tensor([0.6256], requires_grad=True)], 'lr': 0.08274303669727044, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6810]], requires_grad=True), Parameter containing:
# tensor([0.6350], requires_grad=True)], 'lr': 0.0770320408727859, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6910]], requires_grad=True), Parameter containing:
# tensor([0.6466], requires_grad=True)], 'lr': 0.07077075065009983, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6784]], requires_grad=True), Parameter containing:
# tensor([0.6249], requires_grad=True)], 'lr': 0.0640866278420768, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6555]], requires_grad=True), Parameter containing:
# tensor([0.5880], requires_grad=True)], 'lr': 0.057115741913668666, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6440]], requires_grad=True), Parameter containing:
# tensor([0.5613], requires_grad=True)], 'lr': 0.050000000000003826, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6500]], requires_grad=True), Parameter containing:
# tensor([0.5651], requires_grad=True)], 'lr': 0.04288425808633935, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6398]], requires_grad=True), Parameter containing:
# tensor([0.5576], requires_grad=True)], 'lr': 0.035913372157931195, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6403]], requires_grad=True), Parameter containing:
# tensor([0.5500], requires_grad=True)], 'lr': 0.029229249349908146, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6299]], requires_grad=True), Parameter containing:
# tensor([0.5355], requires_grad=True)], 'lr': 0.022967959127221757, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6227]], requires_grad=True), Parameter containing:
# tensor([0.5240], requires_grad=True)], 'lr': 0.0172569633027372, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6217]], requires_grad=True), Parameter containing:
# tensor([0.5190], requires_grad=True)], 'lr': 0.012212521282288107, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6231]], requires_grad=True), Parameter containing:
# tensor([0.5233], requires_grad=True)], 'lr': 0.007937323358441795, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6227]], requires_grad=True), Parameter containing:
# tensor([0.5223], requires_grad=True)], 'lr': 0.00451840023227445, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6236]], requires_grad=True), Parameter containing:
# tensor([0.5242], requires_grad=True)], 'lr': 0.0020253513192752914, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6233]], requires_grad=True), Parameter containing:
# tensor([0.5236], requires_grad=True)], 'lr': 0.000508927905953399, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6233]], requires_grad=True), Parameter containing:
# tensor([0.5236], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6233]], requires_grad=True), Parameter containing:
# tensor([0.5236], requires_grad=True)], 'lr': 0.0005089279059533658, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6231]], requires_grad=True), Parameter containing:
# tensor([0.5234], requires_grad=True)], 'lr': 0.002025351319275325, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6234]], requires_grad=True), Parameter containing:
# tensor([0.5239], requires_grad=True)], 'lr': 0.004518400232274356, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6235]], requires_grad=True), Parameter containing:
# tensor([0.5234], requires_grad=True)], 'lr': 0.007937323358441472, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6256]], requires_grad=True), Parameter containing:
# tensor([0.5259], requires_grad=True)], 'lr': 0.012212521282287723, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6266]], requires_grad=True), Parameter containing:
# tensor([0.5269], requires_grad=True)], 'lr': 0.017256963302737023, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6280]], requires_grad=True), Parameter containing:
# tensor([0.5359], requires_grad=True)], 'lr': 0.022967959127221563, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6280]], requires_grad=True), Parameter containing:
# tensor([0.5391], requires_grad=True)], 'lr': 0.029229249349907935, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6236]], requires_grad=True), Parameter containing:
# tensor([0.5342], requires_grad=True)], 'lr': 0.03591337215793131, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6437]], requires_grad=True), Parameter containing:
# tensor([0.5561], requires_grad=True)], 'lr': 0.04288425808633876, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6480]], requires_grad=True), Parameter containing:
# tensor([0.5599], requires_grad=True)], 'lr': 0.050000000000003944, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6563]], requires_grad=True), Parameter containing:
# tensor([0.5611], requires_grad=True)], 'lr': 0.05711574191366842, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6625]], requires_grad=True), Parameter containing:
# tensor([0.5645], requires_grad=True)], 'lr': 0.06408662784207624, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6677]], requires_grad=True), Parameter containing:
# tensor([0.5829], requires_grad=True)], 'lr': 0.0707707506500996, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6946]], requires_grad=True), Parameter containing:
# tensor([0.6170], requires_grad=True)], 'lr': 0.07703204087278567, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6720]], requires_grad=True), Parameter containing:
# tensor([0.6080], requires_grad=True)], 'lr': 0.08274303669727023, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6878]], requires_grad=True), Parameter containing:
# tensor([0.6265], requires_grad=True)], 'lr': 0.08778747871771958, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6635]], requires_grad=True), Parameter containing:
# tensor([0.6329], requires_grad=True)], 'lr': 0.09206267664156587, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6562]], requires_grad=True), Parameter containing:
# tensor([0.6389], requires_grad=True)], 'lr': 0.09548159976773303, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6721]], requires_grad=True), Parameter containing:
# tensor([0.6538], requires_grad=True)], 'lr': 0.09797464868073233, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6774]], requires_grad=True), Parameter containing:
# tensor([0.6411], requires_grad=True)], 'lr': 0.09949107209405414, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-1.6512]], requires_grad=True), Parameter containing:
# tensor([0.5830], requires_grad=True)], 'lr': 0.10000000000000756, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]

# %%
ax = plt.subplot(1, 1, 1)
plt.scatter(new_X, emp_stand_noised, label='entire dataset', alpha=.75)
plt.scatter(x_trunc_norm, emp_stand_y_trunc, label='truncated dataset', alpha=.75)
plt.plot(norm_data, trunc_emp_stand_ols.predict(norm_data), color='r', label='ols')
plt.plot(norm_data, gt_emp_stand.predict(norm_data), color='green', label='gt')
plt.plot(norm_data, known_emp_res(Tensor(norm_data)).detach().numpy(), label='known emp', color='blue')
plt.legend()
plt.title("Empirical Known Noise Variance Results - Normalized")
ax.set_xlabel("x")
ax.set_ylabel("y")
plt.show()

ax = plt.subplot(1, 1, 1)
plt.plot(unnorm_data, (Tensor(unnorm_data)@known_emp_w_unnorm + known_emp_bias_unnorm).detach().numpy(), color='blue', label='known emp')
plt.plot(unnorm_data, trunc_ols.predict(unnorm_data), color='red', label='ols')
plt.plot(unnorm_data, gt_ols.predict(unnorm_data), color='green', label='gt')
plt.scatter(X, noised, label='entire dataset')
plt.scatter(x_trunc, y_trunc, label='truncated dataset')
plt.legend()
plt.title("Empirical Known Noise Variance Results - UnNormalized")
ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-156bc20a9d9a> in <module>
#       4 plt.plot(norm_data, trunc_emp_stand_ols.predict(norm_data), color='r', label='ols')
#       5 plt.plot(norm_data, gt_emp_stand.predict(norm_data), color='green', label='gt')
# ----> 6 plt.plot(norm_data, known_emp_res(Tensor(norm_data)).detach().numpy(), label='known emp', color='blue')
#       7 plt.legend()
#       8 plt.title("Empirical Known Noise Variance Results - Normalized")
#
# NameError: name 'known_emp_res' is not defined

# %% [markdown]
# Truncated Regression with Known Variance

# %%
args.__setattr__('steps', 1000)
args.__setattr__('batch_size', 1)
args.__setattr__('step_lr', 10)
args.__setattr__('step_lr_gamma', .9)

trunc_reg = TruncatedRegression(phi=phi, alpha=alpha, args=args, bias=True, var=ch.ones(1))
known_res = trunc_reg.fit(x_trunc_norm, stand_y_trunc)
known_weight_unnorm, known_bias_unnorm = (known_res.weight * ch.sqrt(noise_var)) / beta, known_res.bias * ch.sqrt(noise_var)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=633.0), HTML(value='')))
# lr:  [{'params': [Parameter containing:
# tensor([[-0.4520]], requires_grad=True), Parameter containing:
# tensor([0.9158], requires_grad=True)], 'lr': 0.1, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.4540]], requires_grad=True), Parameter containing:
# tensor([0.8370], requires_grad=True)], 'lr': 0.1, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.4643]], requires_grad=True), Parameter containing:
# tensor([0.7909], requires_grad=True)], 'lr': 0.1, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.4655]], requires_grad=True), Parameter containing:
# tensor([0.7425], requires_grad=True)], 'lr': 0.1, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.4772]], requires_grad=True), Parameter containing:
# tensor([0.7679], requires_grad=True)], 'lr': 0.1, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5003]], requires_grad=True), Parameter containing:
# tensor([0.8348], requires_grad=True)], 'lr': 0.1, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.4850]], requires_grad=True), Parameter containing:
# tensor([0.7495], requires_grad=True)], 'lr': 0.1, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5066]], requires_grad=True), Parameter containing:
# tensor([0.6621], requires_grad=True)], 'lr': 0.1, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5069]], requires_grad=True), Parameter containing:
# tensor([0.6584], requires_grad=True)], 'lr': 0.1, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5190]], requires_grad=True), Parameter containing:
# tensor([0.7371], requires_grad=True)], 'lr': 0.09000000000000001, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5171]], requires_grad=True), Parameter containing:
# tensor([0.7276], requires_grad=True)], 'lr': 0.09000000000000001, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5022]], requires_grad=True), Parameter containing:
# tensor([0.7748], requires_grad=True)], 'lr': 0.09000000000000001, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5028]], requires_grad=True), Parameter containing:
# tensor([0.7730], requires_grad=True)], 'lr': 0.09000000000000001, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.4858]], requires_grad=True), Parameter containing:
# tensor([0.6957], requires_grad=True)], 'lr': 0.09000000000000001, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.4833]], requires_grad=True), Parameter containing:
# tensor([0.6294], requires_grad=True)], 'lr': 0.09000000000000001, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.4790]], requires_grad=True), Parameter containing:
# tensor([0.5660], requires_grad=True)], 'lr': 0.09000000000000001, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.4831]], requires_grad=True), Parameter containing:
# tensor([0.5105], requires_grad=True)], 'lr': 0.09000000000000001, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.4886]], requires_grad=True), Parameter containing:
# tensor([0.5201], requires_grad=True)], 'lr': 0.09000000000000001, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.4898]], requires_grad=True), Parameter containing:
# tensor([0.5362], requires_grad=True)], 'lr': 0.09000000000000001, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5095]], requires_grad=True), Parameter containing:
# tensor([0.4863], requires_grad=True)], 'lr': 0.08100000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5243]], requires_grad=True), Parameter containing:
# tensor([0.6214], requires_grad=True)], 'lr': 0.08100000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5305]], requires_grad=True), Parameter containing:
# tensor([0.5832], requires_grad=True)], 'lr': 0.08100000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5387]], requires_grad=True), Parameter containing:
# tensor([0.6220], requires_grad=True)], 'lr': 0.08100000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5294]], requires_grad=True), Parameter containing:
# tensor([0.6093], requires_grad=True)], 'lr': 0.08100000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5247]], requires_grad=True), Parameter containing:
# tensor([0.6387], requires_grad=True)], 'lr': 0.08100000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5248]], requires_grad=True), Parameter containing:
# tensor([0.6380], requires_grad=True)], 'lr': 0.08100000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5248]], requires_grad=True), Parameter containing:
# tensor([0.6382], requires_grad=True)], 'lr': 0.08100000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5231]], requires_grad=True), Parameter containing:
# tensor([0.6700], requires_grad=True)], 'lr': 0.08100000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5303]], requires_grad=True), Parameter containing:
# tensor([0.6911], requires_grad=True)], 'lr': 0.08100000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5278]], requires_grad=True), Parameter containing:
# tensor([0.6661], requires_grad=True)], 'lr': 0.07290000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5355]], requires_grad=True), Parameter containing:
# tensor([0.6073], requires_grad=True)], 'lr': 0.07290000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5088]], requires_grad=True), Parameter containing:
# tensor([0.5372], requires_grad=True)], 'lr': 0.07290000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5070]], requires_grad=True), Parameter containing:
# tensor([0.4795], requires_grad=True)], 'lr': 0.07290000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5087]], requires_grad=True), Parameter containing:
# tensor([0.4582], requires_grad=True)], 'lr': 0.07290000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5068]], requires_grad=True), Parameter containing:
# tensor([0.4410], requires_grad=True)], 'lr': 0.07290000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.4948]], requires_grad=True), Parameter containing:
# tensor([0.3863], requires_grad=True)], 'lr': 0.07290000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.4772]], requires_grad=True), Parameter containing:
# tensor([0.3087], requires_grad=True)], 'lr': 0.07290000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.4840]], requires_grad=True), Parameter containing:
# tensor([0.2820], requires_grad=True)], 'lr': 0.07290000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.4782]], requires_grad=True), Parameter containing:
# tensor([0.2443], requires_grad=True)], 'lr': 0.07290000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.4787]], requires_grad=True), Parameter containing:
# tensor([0.2896], requires_grad=True)], 'lr': 0.06561000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.4785]], requires_grad=True), Parameter containing:
# tensor([0.2887], requires_grad=True)], 'lr': 0.06561000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.4805]], requires_grad=True), Parameter containing:
# tensor([0.2839], requires_grad=True)], 'lr': 0.06561000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.4839]], requires_grad=True), Parameter containing:
# tensor([0.2677], requires_grad=True)], 'lr': 0.06561000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.4817]], requires_grad=True), Parameter containing:
# tensor([0.2586], requires_grad=True)], 'lr': 0.06561000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.4763]], requires_grad=True), Parameter containing:
# tensor([0.3078], requires_grad=True)], 'lr': 0.06561000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.4739]], requires_grad=True), Parameter containing:
# tensor([0.2774], requires_grad=True)], 'lr': 0.06561000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.4710]], requires_grad=True), Parameter containing:
# tensor([0.2861], requires_grad=True)], 'lr': 0.06561000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.4798]], requires_grad=True), Parameter containing:
# tensor([0.3621], requires_grad=True)], 'lr': 0.06561000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.4803]], requires_grad=True), Parameter containing:
# tensor([0.3844], requires_grad=True)], 'lr': 0.06561000000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.4800]], requires_grad=True), Parameter containing:
# tensor([0.3790], requires_grad=True)], 'lr': 0.05904900000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.4914]], requires_grad=True), Parameter containing:
# tensor([0.3186], requires_grad=True)], 'lr': 0.05904900000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5067]], requires_grad=True), Parameter containing:
# tensor([0.2714], requires_grad=True)], 'lr': 0.05904900000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5061]], requires_grad=True), Parameter containing:
# tensor([0.2683], requires_grad=True)], 'lr': 0.05904900000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.4955]], requires_grad=True), Parameter containing:
# tensor([0.2385], requires_grad=True)], 'lr': 0.05904900000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5020]], requires_grad=True), Parameter containing:
# tensor([0.1965], requires_grad=True)], 'lr': 0.05904900000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5080]], requires_grad=True), Parameter containing:
# tensor([0.1821], requires_grad=True)], 'lr': 0.05904900000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5065]], requires_grad=True), Parameter containing:
# tensor([0.1760], requires_grad=True)], 'lr': 0.05904900000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5066]], requires_grad=True), Parameter containing:
# tensor([0.1576], requires_grad=True)], 'lr': 0.05904900000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5012]], requires_grad=True), Parameter containing:
# tensor([0.1197], requires_grad=True)], 'lr': 0.05904900000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5013]], requires_grad=True), Parameter containing:
# tensor([0.1171], requires_grad=True)], 'lr': 0.05314410000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5012]], requires_grad=True), Parameter containing:
# tensor([0.1061], requires_grad=True)], 'lr': 0.05314410000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5072]], requires_grad=True), Parameter containing:
# tensor([0.1236], requires_grad=True)], 'lr': 0.05314410000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5167]], requires_grad=True), Parameter containing:
# tensor([0.1905], requires_grad=True)], 'lr': 0.05314410000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5177]], requires_grad=True), Parameter containing:
# tensor([0.2410], requires_grad=True)], 'lr': 0.05314410000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5358]], requires_grad=True), Parameter containing:
# tensor([0.2020], requires_grad=True)], 'lr': 0.05314410000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5351]], requires_grad=True), Parameter containing:
# tensor([0.1987], requires_grad=True)], 'lr': 0.05314410000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5301]], requires_grad=True), Parameter containing:
# tensor([0.1661], requires_grad=True)], 'lr': 0.05314410000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5331]], requires_grad=True), Parameter containing:
# tensor([0.1465], requires_grad=True)], 'lr': 0.05314410000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5313]], requires_grad=True), Parameter containing:
# tensor([0.1794], requires_grad=True)], 'lr': 0.05314410000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5408]], requires_grad=True), Parameter containing:
# tensor([0.2362], requires_grad=True)], 'lr': 0.04782969000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5412]], requires_grad=True), Parameter containing:
# tensor([0.2388], requires_grad=True)], 'lr': 0.04782969000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5342]], requires_grad=True), Parameter containing:
# tensor([0.2206], requires_grad=True)], 'lr': 0.04782969000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5283]], requires_grad=True), Parameter containing:
# tensor([0.1890], requires_grad=True)], 'lr': 0.04782969000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5295]], requires_grad=True), Parameter containing:
# tensor([0.1693], requires_grad=True)], 'lr': 0.04782969000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5281]], requires_grad=True), Parameter containing:
# tensor([0.1619], requires_grad=True)], 'lr': 0.04782969000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5315]], requires_grad=True), Parameter containing:
# tensor([0.1742], requires_grad=True)], 'lr': 0.04782969000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5306]], requires_grad=True), Parameter containing:
# tensor([0.1852], requires_grad=True)], 'lr': 0.04782969000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5311]], requires_grad=True), Parameter containing:
# tensor([0.1841], requires_grad=True)], 'lr': 0.04782969000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5386]], requires_grad=True), Parameter containing:
# tensor([0.1511], requires_grad=True)], 'lr': 0.04782969000000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5304]], requires_grad=True), Parameter containing:
# tensor([0.1169], requires_grad=True)], 'lr': 0.043046721000000024, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5293]], requires_grad=True), Parameter containing:
# tensor([0.1256], requires_grad=True)], 'lr': 0.043046721000000024, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5303]], requires_grad=True), Parameter containing:
# tensor([0.1308], requires_grad=True)], 'lr': 0.043046721000000024, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5341]], requires_grad=True), Parameter containing:
# tensor([0.1437], requires_grad=True)], 'lr': 0.043046721000000024, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5307]], requires_grad=True), Parameter containing:
# tensor([0.1158], requires_grad=True)], 'lr': 0.043046721000000024, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5318]], requires_grad=True), Parameter containing:
# tensor([0.1341], requires_grad=True)], 'lr': 0.043046721000000024, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5363]], requires_grad=True), Parameter containing:
# tensor([0.1204], requires_grad=True)], 'lr': 0.043046721000000024, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5480]], requires_grad=True), Parameter containing:
# tensor([0.0980], requires_grad=True)], 'lr': 0.043046721000000024, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5428]], requires_grad=True), Parameter containing:
# tensor([0.0771], requires_grad=True)], 'lr': 0.043046721000000024, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5374]], requires_grad=True), Parameter containing:
# tensor([0.1361], requires_grad=True)], 'lr': 0.043046721000000024, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5414]], requires_grad=True), Parameter containing:
# tensor([0.1445], requires_grad=True)], 'lr': 0.03874204890000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5337]], requires_grad=True), Parameter containing:
# tensor([0.1143], requires_grad=True)], 'lr': 0.03874204890000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5344]], requires_grad=True), Parameter containing:
# tensor([0.1080], requires_grad=True)], 'lr': 0.03874204890000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5391]], requires_grad=True), Parameter containing:
# tensor([0.0819], requires_grad=True)], 'lr': 0.03874204890000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5374]], requires_grad=True), Parameter containing:
# tensor([0.0617], requires_grad=True)], 'lr': 0.03874204890000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5266]], requires_grad=True), Parameter containing:
# tensor([0.0754], requires_grad=True)], 'lr': 0.03874204890000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5270]], requires_grad=True), Parameter containing:
# tensor([0.0844], requires_grad=True)], 'lr': 0.03874204890000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5272]], requires_grad=True), Parameter containing:
# tensor([0.0839], requires_grad=True)], 'lr': 0.03874204890000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5291]], requires_grad=True), Parameter containing:
# tensor([0.0796], requires_grad=True)], 'lr': 0.03874204890000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5330]], requires_grad=True), Parameter containing:
# tensor([0.1021], requires_grad=True)], 'lr': 0.03874204890000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5401]], requires_grad=True), Parameter containing:
# tensor([0.0637], requires_grad=True)], 'lr': 0.03486784401000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5436]], requires_grad=True), Parameter containing:
# tensor([0.0843], requires_grad=True)], 'lr': 0.03486784401000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5449]], requires_grad=True), Parameter containing:
# tensor([0.0811], requires_grad=True)], 'lr': 0.03486784401000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5466]], requires_grad=True), Parameter containing:
# tensor([0.1029], requires_grad=True)], 'lr': 0.03486784401000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5453]], requires_grad=True), Parameter containing:
# tensor([0.1109], requires_grad=True)], 'lr': 0.03486784401000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5366]], requires_grad=True), Parameter containing:
# tensor([0.0857], requires_grad=True)], 'lr': 0.03486784401000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5328]], requires_grad=True), Parameter containing:
# tensor([0.0705], requires_grad=True)], 'lr': 0.03486784401000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5314]], requires_grad=True), Parameter containing:
# tensor([0.0423], requires_grad=True)], 'lr': 0.03486784401000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5284]], requires_grad=True), Parameter containing:
# tensor([0.0274], requires_grad=True)], 'lr': 0.03486784401000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5239]], requires_grad=True), Parameter containing:
# tensor([0.0151], requires_grad=True)], 'lr': 0.03486784401000002, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5258]], requires_grad=True), Parameter containing:
# tensor([0.0209], requires_grad=True)], 'lr': 0.03138105960900001, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5267]], requires_grad=True), Parameter containing:
# tensor([0.0308], requires_grad=True)], 'lr': 0.03138105960900001, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5268]], requires_grad=True), Parameter containing:
# tensor([0.0299], requires_grad=True)], 'lr': 0.03138105960900001, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5447]], requires_grad=True), Parameter containing:
# tensor([0.0846], requires_grad=True)], 'lr': 0.03138105960900001, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5453]], requires_grad=True), Parameter containing:
# tensor([0.0885], requires_grad=True)], 'lr': 0.03138105960900001, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5453]], requires_grad=True), Parameter containing:
# tensor([0.0850], requires_grad=True)], 'lr': 0.03138105960900001, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5453]], requires_grad=True), Parameter containing:
# tensor([0.0982], requires_grad=True)], 'lr': 0.03138105960900001, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5413]], requires_grad=True), Parameter containing:
# tensor([0.1091], requires_grad=True)], 'lr': 0.03138105960900001, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5469]], requires_grad=True), Parameter containing:
# tensor([0.1235], requires_grad=True)], 'lr': 0.03138105960900001, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5463]], requires_grad=True), Parameter containing:
# tensor([0.0992], requires_grad=True)], 'lr': 0.03138105960900001, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5324]], requires_grad=True), Parameter containing:
# tensor([0.1465], requires_grad=True)], 'lr': 0.028242953648100012, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5366]], requires_grad=True), Parameter containing:
# tensor([0.1552], requires_grad=True)], 'lr': 0.028242953648100012, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5361]], requires_grad=True), Parameter containing:
# tensor([0.1415], requires_grad=True)], 'lr': 0.028242953648100012, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5367]], requires_grad=True), Parameter containing:
# tensor([0.1422], requires_grad=True)], 'lr': 0.028242953648100012, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5406]], requires_grad=True), Parameter containing:
# tensor([0.1220], requires_grad=True)], 'lr': 0.028242953648100012, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5373]], requires_grad=True), Parameter containing:
# tensor([0.1164], requires_grad=True)], 'lr': 0.028242953648100012, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5399]], requires_grad=True), Parameter containing:
# tensor([0.1248], requires_grad=True)], 'lr': 0.028242953648100012, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5322]], requires_grad=True), Parameter containing:
# tensor([0.1037], requires_grad=True)], 'lr': 0.028242953648100012, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5244]], requires_grad=True), Parameter containing:
# tensor([0.0909], requires_grad=True)], 'lr': 0.028242953648100012, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5242]], requires_grad=True), Parameter containing:
# tensor([0.1060], requires_grad=True)], 'lr': 0.028242953648100012, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5230]], requires_grad=True), Parameter containing:
# tensor([0.1130], requires_grad=True)], 'lr': 0.025418658283290013, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5220]], requires_grad=True), Parameter containing:
# tensor([0.1276], requires_grad=True)], 'lr': 0.025418658283290013, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5212]], requires_grad=True), Parameter containing:
# tensor([0.1257], requires_grad=True)], 'lr': 0.025418658283290013, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5221]], requires_grad=True), Parameter containing:
# tensor([0.1295], requires_grad=True)], 'lr': 0.025418658283290013, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5228]], requires_grad=True), Parameter containing:
# tensor([0.1253], requires_grad=True)], 'lr': 0.025418658283290013, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5307]], requires_grad=True), Parameter containing:
# tensor([0.1463], requires_grad=True)], 'lr': 0.025418658283290013, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5281]], requires_grad=True), Parameter containing:
# tensor([0.1578], requires_grad=True)], 'lr': 0.025418658283290013, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5294]], requires_grad=True), Parameter containing:
# tensor([0.1601], requires_grad=True)], 'lr': 0.025418658283290013, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5239]], requires_grad=True), Parameter containing:
# tensor([0.1396], requires_grad=True)], 'lr': 0.025418658283290013, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5210]], requires_grad=True), Parameter containing:
# tensor([0.1318], requires_grad=True)], 'lr': 0.025418658283290013, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5170]], requires_grad=True), Parameter containing:
# tensor([0.1155], requires_grad=True)], 'lr': 0.022876792454961013, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5192]], requires_grad=True), Parameter containing:
# tensor([0.1077], requires_grad=True)], 'lr': 0.022876792454961013, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5192]], requires_grad=True), Parameter containing:
# tensor([0.1027], requires_grad=True)], 'lr': 0.022876792454961013, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5200]], requires_grad=True), Parameter containing:
# tensor([0.0904], requires_grad=True)], 'lr': 0.022876792454961013, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5180]], requires_grad=True), Parameter containing:
# tensor([0.0796], requires_grad=True)], 'lr': 0.022876792454961013, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5125]], requires_grad=True), Parameter containing:
# tensor([0.0616], requires_grad=True)], 'lr': 0.022876792454961013, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5130]], requires_grad=True), Parameter containing:
# tensor([0.0607], requires_grad=True)], 'lr': 0.022876792454961013, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5052]], requires_grad=True), Parameter containing:
# tensor([0.0426], requires_grad=True)], 'lr': 0.022876792454961013, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5039]], requires_grad=True), Parameter containing:
# tensor([0.0306], requires_grad=True)], 'lr': 0.022876792454961013, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5114]], requires_grad=True), Parameter containing:
# tensor([0.0614], requires_grad=True)], 'lr': 0.022876792454961013, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5106]], requires_grad=True), Parameter containing:
# tensor([0.0512], requires_grad=True)], 'lr': 0.020589113209464913, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5104]], requires_grad=True), Parameter containing:
# tensor([0.0672], requires_grad=True)], 'lr': 0.020589113209464913, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5078]], requires_grad=True), Parameter containing:
# tensor([0.0759], requires_grad=True)], 'lr': 0.020589113209464913, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5024]], requires_grad=True), Parameter containing:
# tensor([0.0982], requires_grad=True)], 'lr': 0.020589113209464913, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5052]], requires_grad=True), Parameter containing:
# tensor([0.1035], requires_grad=True)], 'lr': 0.020589113209464913, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5073]], requires_grad=True), Parameter containing:
# tensor([0.1074], requires_grad=True)], 'lr': 0.020589113209464913, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5059]], requires_grad=True), Parameter containing:
# tensor([0.0963], requires_grad=True)], 'lr': 0.020589113209464913, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5095]], requires_grad=True), Parameter containing:
# tensor([0.1033], requires_grad=True)], 'lr': 0.020589113209464913, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5101]], requires_grad=True), Parameter containing:
# tensor([0.1311], requires_grad=True)], 'lr': 0.020589113209464913, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5121]], requires_grad=True), Parameter containing:
# tensor([0.1359], requires_grad=True)], 'lr': 0.020589113209464913, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5164]], requires_grad=True), Parameter containing:
# tensor([0.1271], requires_grad=True)], 'lr': 0.01853020188851842, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5139]], requires_grad=True), Parameter containing:
# tensor([0.1402], requires_grad=True)], 'lr': 0.01853020188851842, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5139]], requires_grad=True), Parameter containing:
# tensor([0.1369], requires_grad=True)], 'lr': 0.01853020188851842, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5165]], requires_grad=True), Parameter containing:
# tensor([0.1446], requires_grad=True)], 'lr': 0.01853020188851842, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5138]], requires_grad=True), Parameter containing:
# tensor([0.1289], requires_grad=True)], 'lr': 0.01853020188851842, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5136]], requires_grad=True), Parameter containing:
# tensor([0.1281], requires_grad=True)], 'lr': 0.01853020188851842, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5140]], requires_grad=True), Parameter containing:
# tensor([0.1180], requires_grad=True)], 'lr': 0.01853020188851842, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5185]], requires_grad=True), Parameter containing:
# tensor([0.1082], requires_grad=True)], 'lr': 0.01853020188851842, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5232]], requires_grad=True), Parameter containing:
# tensor([0.1359], requires_grad=True)], 'lr': 0.01853020188851842, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5234]], requires_grad=True), Parameter containing:
# tensor([0.1348], requires_grad=True)], 'lr': 0.01853020188851842, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5194]], requires_grad=True), Parameter containing:
# tensor([0.1290], requires_grad=True)], 'lr': 0.01667718169966658, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5114]], requires_grad=True), Parameter containing:
# tensor([0.1503], requires_grad=True)], 'lr': 0.01667718169966658, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5091]], requires_grad=True), Parameter containing:
# tensor([0.1527], requires_grad=True)], 'lr': 0.01667718169966658, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5095]], requires_grad=True), Parameter containing:
# tensor([0.1610], requires_grad=True)], 'lr': 0.01667718169966658, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5102]], requires_grad=True), Parameter containing:
# tensor([0.1585], requires_grad=True)], 'lr': 0.01667718169966658, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5124]], requires_grad=True), Parameter containing:
# tensor([0.1509], requires_grad=True)], 'lr': 0.01667718169966658, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5122]], requires_grad=True), Parameter containing:
# tensor([0.1486], requires_grad=True)], 'lr': 0.01667718169966658, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5139]], requires_grad=True), Parameter containing:
# tensor([0.1413], requires_grad=True)], 'lr': 0.01667718169966658, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5116]], requires_grad=True), Parameter containing:
# tensor([0.1503], requires_grad=True)], 'lr': 0.01667718169966658, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5081]], requires_grad=True), Parameter containing:
# tensor([0.1438], requires_grad=True)], 'lr': 0.01667718169966658, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5080]], requires_grad=True), Parameter containing:
# tensor([0.1440], requires_grad=True)], 'lr': 0.015009463529699923, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5087]], requires_grad=True), Parameter containing:
# tensor([0.1480], requires_grad=True)], 'lr': 0.015009463529699923, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5094]], requires_grad=True), Parameter containing:
# tensor([0.1431], requires_grad=True)], 'lr': 0.015009463529699923, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5071]], requires_grad=True), Parameter containing:
# tensor([0.1476], requires_grad=True)], 'lr': 0.015009463529699923, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# ...
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 3.2292460179985633e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 3.2292460179985633e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 3.2292460179985633e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.906321416198707e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.906321416198707e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.906321416198707e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.906321416198707e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.906321416198707e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.906321416198707e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.906321416198707e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.906321416198707e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.906321416198707e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.906321416198707e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.615689274578837e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.615689274578837e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.615689274578837e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.615689274578837e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.615689274578837e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.615689274578837e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.615689274578837e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.615689274578837e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.615689274578837e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.615689274578837e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.354120347120953e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.354120347120953e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.354120347120953e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.354120347120953e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.354120347120953e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.354120347120953e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.354120347120953e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.354120347120953e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.354120347120953e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.354120347120953e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.118708312408858e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.118708312408858e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.118708312408858e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.118708312408858e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.118708312408858e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.118708312408858e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.118708312408858e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.118708312408858e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.118708312408858e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 2.118708312408858e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 1.9068374811679722e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 1.9068374811679722e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 1.9068374811679722e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 1.9068374811679722e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 1.9068374811679722e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 1.9068374811679722e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 1.9068374811679722e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 1.9068374811679722e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 1.9068374811679722e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 1.9068374811679722e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 1.716153733051175e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 1.716153733051175e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 1.716153733051175e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 1.716153733051175e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 1.716153733051175e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 1.716153733051175e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.5569]], requires_grad=True), Parameter containing:
# tensor([0.2463], requires_grad=True)], 'lr': 1.716153733051175e-07, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}]

# %%
ax = plt.subplot(1, 1, 1)
plt.scatter(new_X, stand_noised, label='entire dataset', alpha=.75)
plt.scatter(x_trunc_norm, stand_y_trunc, label='truncated dataset', alpha=.75)
plt.plot(norm_data, trunc_stand_ols.predict(norm_data), color='r', label='ols')
plt.plot(norm_data, gt_stand.predict(norm_data), color='green', label='gt')
plt.plot(norm_data, known_res(Tensor(norm_data)).detach().numpy(), label='known', color='blue')
plt.legend()
plt.title("Known Noise Variance - Normalized")
ax.set_xlabel("x")
ax.set_ylabel("y")
plt.show()

ax = plt.subplot(1, 1, 1)
plt.scatter(X, noised, label='entire dataset', alpha=.75)
plt.scatter(x_trunc, y_trunc, label='truncated dataset', alpha=.75)
plt.plot(unnorm_data, trunc_ols.predict(unnorm_data), color='r', label='ols')
plt.plot(unnorm_data, gt_ols.predict(unnorm_data), color='green', label='gt')
plt.plot(unnorm_data, (Tensor(unnorm_data)@known_weight_unnorm + known_bias_unnorm).detach().numpy(), label='known', color='blue')
plt.legend()
plt.title("Known Noise Variance - UnNormalized")
ax.set_xlabel("x")
ax.set_ylabel("y")
plt.show()

# %% [markdown]
# Truncated Regression with Unknown Noise Variance

# %%
args.__setattr__('steps', 1000)
args.__setattr__('batch_size', 10)
args.__setattr__('step_lr_gamma', 1.0)
trunc_reg = TruncatedRegression(phi=phi, alpha=alpha, args=args, bias=True)
unknown_res = trunc_reg.fit(x_trunc_norm, emp_stand_y_trunc)
unknown_var = unknown_res.lambda_.inverse()
unknown_weight_unnorm, unknown_bias_unnorm = (((unknown_res.weight * unknown_var) * ch.sqrt(emp_noise_var)) / beta).detach().numpy(), ((unknown_res.bias * unknown_var) * ch.sqrt(emp_noise_var)).detach().numpy()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=64.0), HTML(value='')))
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6788]], requires_grad=True), Parameter containing:
# tensor([1.3742], requires_grad=True)], 'lr': 0.00037593984962406017, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.]], requires_grad=True)], 'lr': 3.759398496240601e-05, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6788]], requires_grad=True), Parameter containing:
# tensor([1.3741], requires_grad=True)], 'lr': 0.0007518796992481203, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0000]], requires_grad=True)], 'lr': 7.518796992481203e-05, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6788]], requires_grad=True), Parameter containing:
# tensor([1.3740], requires_grad=True)], 'lr': 0.0011278195488721805, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0000]], requires_grad=True)], 'lr': 0.00011278195488721805, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6790]], requires_grad=True), Parameter containing:
# tensor([1.3735], requires_grad=True)], 'lr': 0.0015037593984962407, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0001]], requires_grad=True)], 'lr': 0.00015037593984962405, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6791]], requires_grad=True), Parameter containing:
# tensor([1.3731], requires_grad=True)], 'lr': 0.0018796992481203006, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0001]], requires_grad=True)], 'lr': 0.00018796992481203006, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6792]], requires_grad=True), Parameter containing:
# tensor([1.3725], requires_grad=True)], 'lr': 0.002255639097744361, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0002]], requires_grad=True)], 'lr': 0.0002255639097744361, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6792]], requires_grad=True), Parameter containing:
# tensor([1.3716], requires_grad=True)], 'lr': 0.002631578947368421, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0002]], requires_grad=True)], 'lr': 0.0002631578947368421, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6794]], requires_grad=True), Parameter containing:
# tensor([1.3715], requires_grad=True)], 'lr': 0.0030075187969924814, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0002]], requires_grad=True)], 'lr': 0.0003007518796992481, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6795]], requires_grad=True), Parameter containing:
# tensor([1.3709], requires_grad=True)], 'lr': 0.0033834586466165413, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0003]], requires_grad=True)], 'lr': 0.0003383458646616541, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6791]], requires_grad=True), Parameter containing:
# tensor([1.3714], requires_grad=True)], 'lr': 0.0037593984962406013, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0002]], requires_grad=True)], 'lr': 0.0003759398496240601, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6789]], requires_grad=True), Parameter containing:
# tensor([1.3710], requires_grad=True)], 'lr': 0.004135338345864661, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0002]], requires_grad=True)], 'lr': 0.0004135338345864661, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6786]], requires_grad=True), Parameter containing:
# tensor([1.3715], requires_grad=True)], 'lr': 0.004511278195488722, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0002]], requires_grad=True)], 'lr': 0.0004511278195488722, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6788]], requires_grad=True), Parameter containing:
# tensor([1.3700], requires_grad=True)], 'lr': 0.004887218045112782, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0004]], requires_grad=True)], 'lr': 0.0004887218045112781, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6791]], requires_grad=True), Parameter containing:
# tensor([1.3722], requires_grad=True)], 'lr': 0.005263157894736842, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9998]], requires_grad=True)], 'lr': 0.0005263157894736842, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6801]], requires_grad=True), Parameter containing:
# tensor([1.3697], requires_grad=True)], 'lr': 0.005639097744360902, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0000]], requires_grad=True)], 'lr': 0.0005639097744360903, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6799]], requires_grad=True), Parameter containing:
# tensor([1.3719], requires_grad=True)], 'lr': 0.006015037593984963, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9996]], requires_grad=True)], 'lr': 0.0006015037593984962, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6798]], requires_grad=True), Parameter containing:
# tensor([1.3700], requires_grad=True)], 'lr': 0.006390977443609023, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0000]], requires_grad=True)], 'lr': 0.0006390977443609023, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6791]], requires_grad=True), Parameter containing:
# tensor([1.3673], requires_grad=True)], 'lr': 0.006766917293233083, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0004]], requires_grad=True)], 'lr': 0.0006766917293233082, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6787]], requires_grad=True), Parameter containing:
# tensor([1.3661], requires_grad=True)], 'lr': 0.007142857142857143, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0006]], requires_grad=True)], 'lr': 0.0007142857142857143, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6781]], requires_grad=True), Parameter containing:
# tensor([1.3657], requires_grad=True)], 'lr': 0.007518796992481203, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0007]], requires_grad=True)], 'lr': 0.0007518796992481202, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6778]], requires_grad=True), Parameter containing:
# tensor([1.3613], requires_grad=True)], 'lr': 0.007894736842105263, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0014]], requires_grad=True)], 'lr': 0.0007894736842105263, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6781]], requires_grad=True), Parameter containing:
# tensor([1.3555], requires_grad=True)], 'lr': 0.008270676691729323, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0022]], requires_grad=True)], 'lr': 0.0008270676691729323, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6780]], requires_grad=True), Parameter containing:
# tensor([1.3524], requires_grad=True)], 'lr': 0.008646616541353383, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0028]], requires_grad=True)], 'lr': 0.0008646616541353383, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6785]], requires_grad=True), Parameter containing:
# tensor([1.3544], requires_grad=True)], 'lr': 0.009022556390977444, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0024]], requires_grad=True)], 'lr': 0.0009022556390977444, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6784]], requires_grad=True), Parameter containing:
# tensor([1.3504], requires_grad=True)], 'lr': 0.009398496240601503, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0031]], requires_grad=True)], 'lr': 0.0009398496240601503, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6780]], requires_grad=True), Parameter containing:
# tensor([1.3447], requires_grad=True)], 'lr': 0.009774436090225564, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0038]], requires_grad=True)], 'lr': 0.0009774436090225563, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6781]], requires_grad=True), Parameter containing:
# tensor([1.3445], requires_grad=True)], 'lr': 0.010150375939849625, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0036]], requires_grad=True)], 'lr': 0.0010150375939849624, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6790]], requires_grad=True), Parameter containing:
# tensor([1.3493], requires_grad=True)], 'lr': 0.010526315789473684, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0023]], requires_grad=True)], 'lr': 0.0010526315789473684, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6777]], requires_grad=True), Parameter containing:
# tensor([1.3462], requires_grad=True)], 'lr': 0.010902255639097745, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0027]], requires_grad=True)], 'lr': 0.0010902255639097743, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6793]], requires_grad=True), Parameter containing:
# tensor([1.3418], requires_grad=True)], 'lr': 0.011278195488721804, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0029]], requires_grad=True)], 'lr': 0.0011278195488721805, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6797]], requires_grad=True), Parameter containing:
# tensor([1.3418], requires_grad=True)], 'lr': 0.011654135338345865, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0028]], requires_grad=True)], 'lr': 0.0011654135338345865, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6815]], requires_grad=True), Parameter containing:
# tensor([1.3406], requires_grad=True)], 'lr': 0.012030075187969926, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0030]], requires_grad=True)], 'lr': 0.0012030075187969924, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6814]], requires_grad=True), Parameter containing:
# tensor([1.3331], requires_grad=True)], 'lr': 0.012406015037593985, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0041]], requires_grad=True)], 'lr': 0.0012406015037593984, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6814]], requires_grad=True), Parameter containing:
# tensor([1.3317], requires_grad=True)], 'lr': 0.012781954887218045, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0045]], requires_grad=True)], 'lr': 0.0012781954887218045, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6809]], requires_grad=True), Parameter containing:
# tensor([1.3293], requires_grad=True)], 'lr': 0.013157894736842105, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0047]], requires_grad=True)], 'lr': 0.0013157894736842105, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6809]], requires_grad=True), Parameter containing:
# tensor([1.3273], requires_grad=True)], 'lr': 0.013533834586466165, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0052]], requires_grad=True)], 'lr': 0.0013533834586466164, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6825]], requires_grad=True), Parameter containing:
# tensor([1.3303], requires_grad=True)], 'lr': 0.013909774436090226, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0043]], requires_grad=True)], 'lr': 0.0013909774436090224, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6829]], requires_grad=True), Parameter containing:
# tensor([1.3303], requires_grad=True)], 'lr': 0.014285714285714285, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0045]], requires_grad=True)], 'lr': 0.0014285714285714286, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6845]], requires_grad=True), Parameter containing:
# tensor([1.3277], requires_grad=True)], 'lr': 0.014661654135338346, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0042]], requires_grad=True)], 'lr': 0.0014661654135338345, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6838]], requires_grad=True), Parameter containing:
# tensor([1.3261], requires_grad=True)], 'lr': 0.015037593984962405, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0043]], requires_grad=True)], 'lr': 0.0015037593984962405, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6830]], requires_grad=True), Parameter containing:
# tensor([1.3247], requires_grad=True)], 'lr': 0.015413533834586466, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0049]], requires_grad=True)], 'lr': 0.0015413533834586466, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6811]], requires_grad=True), Parameter containing:
# tensor([1.3193], requires_grad=True)], 'lr': 0.015789473684210527, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0055]], requires_grad=True)], 'lr': 0.0015789473684210526, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6791]], requires_grad=True), Parameter containing:
# tensor([1.3288], requires_grad=True)], 'lr': 0.016165413533834588, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0025]], requires_grad=True)], 'lr': 0.0016165413533834585, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6795]], requires_grad=True), Parameter containing:
# tensor([1.3288], requires_grad=True)], 'lr': 0.016541353383458645, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0022]], requires_grad=True)], 'lr': 0.0016541353383458645, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6780]], requires_grad=True), Parameter containing:
# tensor([1.3210], requires_grad=True)], 'lr': 0.016917293233082706, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0033]], requires_grad=True)], 'lr': 0.0016917293233082707, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6758]], requires_grad=True), Parameter containing:
# tensor([1.3164], requires_grad=True)], 'lr': 0.017293233082706767, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0039]], requires_grad=True)], 'lr': 0.0017293233082706766, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6753]], requires_grad=True), Parameter containing:
# tensor([1.3077], requires_grad=True)], 'lr': 0.017669172932330827, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0050]], requires_grad=True)], 'lr': 0.0017669172932330826, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6770]], requires_grad=True), Parameter containing:
# tensor([1.3151], requires_grad=True)], 'lr': 0.01804511278195489, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0034]], requires_grad=True)], 'lr': 0.0018045112781954887, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6794]], requires_grad=True), Parameter containing:
# tensor([1.3062], requires_grad=True)], 'lr': 0.018421052631578946, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0047]], requires_grad=True)], 'lr': 0.0018421052631578947, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6826]], requires_grad=True), Parameter containing:
# tensor([1.3098], requires_grad=True)], 'lr': 0.018796992481203006, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0027]], requires_grad=True)], 'lr': 0.0018796992481203006, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6832]], requires_grad=True), Parameter containing:
# tensor([1.3059], requires_grad=True)], 'lr': 0.019172932330827067, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0033]], requires_grad=True)], 'lr': 0.0019172932330827066, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6849]], requires_grad=True), Parameter containing:
# tensor([1.2983], requires_grad=True)], 'lr': 0.019548872180451128, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0044]], requires_grad=True)], 'lr': 0.0019548872180451126, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6851]], requires_grad=True), Parameter containing:
# tensor([1.2960], requires_grad=True)], 'lr': 0.01992481203007519, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0049]], requires_grad=True)], 'lr': 0.0019924812030075187, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6870]], requires_grad=True), Parameter containing:
# tensor([1.2977], requires_grad=True)], 'lr': 0.02030075187969925, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0047]], requires_grad=True)], 'lr': 0.002030075187969925, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6881]], requires_grad=True), Parameter containing:
# tensor([1.2893], requires_grad=True)], 'lr': 0.020676691729323307, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0059]], requires_grad=True)], 'lr': 0.0020676691729323306, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6863]], requires_grad=True), Parameter containing:
# tensor([1.2790], requires_grad=True)], 'lr': 0.021052631578947368, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0075]], requires_grad=True)], 'lr': 0.002105263157894737, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6807]], requires_grad=True), Parameter containing:
# tensor([1.2678], requires_grad=True)], 'lr': 0.02142857142857143, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0090]], requires_grad=True)], 'lr': 0.002142857142857143, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6815]], requires_grad=True), Parameter containing:
# tensor([1.2741], requires_grad=True)], 'lr': 0.02180451127819549, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0080]], requires_grad=True)], 'lr': 0.0021804511278195487, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6785]], requires_grad=True), Parameter containing:
# tensor([1.2611], requires_grad=True)], 'lr': 0.02218045112781955, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0097]], requires_grad=True)], 'lr': 0.002218045112781955, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6789]], requires_grad=True), Parameter containing:
# tensor([1.2677], requires_grad=True)], 'lr': 0.022556390977443608, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0060]], requires_grad=True)], 'lr': 0.002255639097744361, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6801]], requires_grad=True), Parameter containing:
# tensor([1.2774], requires_grad=True)], 'lr': 0.02293233082706767, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0035]], requires_grad=True)], 'lr': 0.0022932330827067668, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6827]], requires_grad=True), Parameter containing:
# tensor([1.2857], requires_grad=True)], 'lr': 0.02330827067669173, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0006]], requires_grad=True)], 'lr': 0.002330827067669173, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6821]], requires_grad=True), Parameter containing:
# tensor([1.2824], requires_grad=True)], 'lr': 0.02368421052631579, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[1.0010]], requires_grad=True)], 'lr': 0.0023684210526315787, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6791]], requires_grad=True), Parameter containing:
# tensor([1.2919], requires_grad=True)], 'lr': 0.02406015037593985, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9997]], requires_grad=True)], 'lr': 0.002406015037593985, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# HBox(children=(FloatProgress(value=0.0, max=64.0), HTML(value='')))
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6792]], requires_grad=True), Parameter containing:
# tensor([1.2959], requires_grad=True)], 'lr': 0.02443609022556391, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9986]], requires_grad=True)], 'lr': 0.002443609022556391, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6812]], requires_grad=True), Parameter containing:
# tensor([1.2931], requires_grad=True)], 'lr': 0.02481203007518797, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9976]], requires_grad=True)], 'lr': 0.0024812030075187968, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6816]], requires_grad=True), Parameter containing:
# tensor([1.2864], requires_grad=True)], 'lr': 0.025187969924812027, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9982]], requires_grad=True)], 'lr': 0.0025187969924812025, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6833]], requires_grad=True), Parameter containing:
# tensor([1.2969], requires_grad=True)], 'lr': 0.02556390977443609, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9952]], requires_grad=True)], 'lr': 0.002556390977443609, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6835]], requires_grad=True), Parameter containing:
# tensor([1.2933], requires_grad=True)], 'lr': 0.02593984962406015, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9955]], requires_grad=True)], 'lr': 0.0025939849624060153, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6820]], requires_grad=True), Parameter containing:
# tensor([1.2903], requires_grad=True)], 'lr': 0.02631578947368421, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9959]], requires_grad=True)], 'lr': 0.002631578947368421, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6833]], requires_grad=True), Parameter containing:
# tensor([1.2895], requires_grad=True)], 'lr': 0.026691729323308266, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9953]], requires_grad=True)], 'lr': 0.0026691729323308267, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6849]], requires_grad=True), Parameter containing:
# tensor([1.2763], requires_grad=True)], 'lr': 0.02706766917293233, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9967]], requires_grad=True)], 'lr': 0.002706766917293233, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6837]], requires_grad=True), Parameter containing:
# tensor([1.2790], requires_grad=True)], 'lr': 0.027443609022556395, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9963]], requires_grad=True)], 'lr': 0.002744360902255639, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6879]], requires_grad=True), Parameter containing:
# tensor([1.3044], requires_grad=True)], 'lr': 0.027819548872180452, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9905]], requires_grad=True)], 'lr': 0.002781954887218045, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6852]], requires_grad=True), Parameter containing:
# tensor([1.3049], requires_grad=True)], 'lr': 0.02819548872180451, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9898]], requires_grad=True)], 'lr': 0.0028195488721804505, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6865]], requires_grad=True), Parameter containing:
# tensor([1.3025], requires_grad=True)], 'lr': 0.02857142857142857, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9894]], requires_grad=True)], 'lr': 0.002857142857142857, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6859]], requires_grad=True), Parameter containing:
# tensor([1.3007], requires_grad=True)], 'lr': 0.028947368421052635, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9901]], requires_grad=True)], 'lr': 0.0028947368421052633, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6830]], requires_grad=True), Parameter containing:
# tensor([1.2890], requires_grad=True)], 'lr': 0.029323308270676692, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9918]], requires_grad=True)], 'lr': 0.002932330827067669, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6819]], requires_grad=True), Parameter containing:
# tensor([1.2860], requires_grad=True)], 'lr': 0.02969924812030075, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9916]], requires_grad=True)], 'lr': 0.0029699248120300748, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6792]], requires_grad=True), Parameter containing:
# tensor([1.2891], requires_grad=True)], 'lr': 0.03007518796992481, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9910]], requires_grad=True)], 'lr': 0.003007518796992481, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6806]], requires_grad=True), Parameter containing:
# tensor([1.2903], requires_grad=True)], 'lr': 0.030451127819548875, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9887]], requires_grad=True)], 'lr': 0.0030451127819548876, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6792]], requires_grad=True), Parameter containing:
# tensor([1.2761], requires_grad=True)], 'lr': 0.030827067669172932, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9904]], requires_grad=True)], 'lr': 0.0030827067669172933, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6770]], requires_grad=True), Parameter containing:
# tensor([1.2614], requires_grad=True)], 'lr': 0.03120300751879699, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9921]], requires_grad=True)], 'lr': 0.003120300751879699, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6768]], requires_grad=True), Parameter containing:
# tensor([1.2616], requires_grad=True)], 'lr': 0.031578947368421054, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9918]], requires_grad=True)], 'lr': 0.003157894736842105, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6788]], requires_grad=True), Parameter containing:
# tensor([1.2568], requires_grad=True)], 'lr': 0.03195488721804512, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9918]], requires_grad=True)], 'lr': 0.0031954887218045114, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6771]], requires_grad=True), Parameter containing:
# tensor([1.2393], requires_grad=True)], 'lr': 0.032330827067669175, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9942]], requires_grad=True)], 'lr': 0.003233082706766917, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6842]], requires_grad=True), Parameter containing:
# tensor([1.2577], requires_grad=True)], 'lr': 0.03270676691729323, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9904]], requires_grad=True)], 'lr': 0.003270676691729323, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6824]], requires_grad=True), Parameter containing:
# tensor([1.2517], requires_grad=True)], 'lr': 0.03308270676691729, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9917]], requires_grad=True)], 'lr': 0.003308270676691729, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6801]], requires_grad=True), Parameter containing:
# tensor([1.2604], requires_grad=True)], 'lr': 0.033458646616541354, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9897]], requires_grad=True)], 'lr': 0.0033458646616541356, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6819]], requires_grad=True), Parameter containing:
# tensor([1.2709], requires_grad=True)], 'lr': 0.03383458646616541, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9871]], requires_grad=True)], 'lr': 0.0033834586466165413, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6776]], requires_grad=True), Parameter containing:
# tensor([1.2526], requires_grad=True)], 'lr': 0.03421052631578947, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9897]], requires_grad=True)], 'lr': 0.003421052631578947, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6764]], requires_grad=True), Parameter containing:
# tensor([1.2557], requires_grad=True)], 'lr': 0.03458646616541353, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9893]], requires_grad=True)], 'lr': 0.0034586466165413532, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6757]], requires_grad=True), Parameter containing:
# tensor([1.2556], requires_grad=True)], 'lr': 0.0349624060150376, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9898]], requires_grad=True)], 'lr': 0.0034962406015037594, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6765]], requires_grad=True), Parameter containing:
# tensor([1.2551], requires_grad=True)], 'lr': 0.035338345864661655, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9892]], requires_grad=True)], 'lr': 0.003533834586466165, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6765]], requires_grad=True), Parameter containing:
# tensor([1.2385], requires_grad=True)], 'lr': 0.03571428571428571, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9923]], requires_grad=True)], 'lr': 0.003571428571428571, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6801]], requires_grad=True), Parameter containing:
# tensor([1.2595], requires_grad=True)], 'lr': 0.03609022556390978, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9884]], requires_grad=True)], 'lr': 0.0036090225563909775, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6797]], requires_grad=True), Parameter containing:
# tensor([1.2444], requires_grad=True)], 'lr': 0.036466165413533834, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9908]], requires_grad=True)], 'lr': 0.0036466165413533837, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6805]], requires_grad=True), Parameter containing:
# tensor([1.2344], requires_grad=True)], 'lr': 0.03684210526315789, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9919]], requires_grad=True)], 'lr': 0.0036842105263157894, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6808]], requires_grad=True), Parameter containing:
# tensor([1.2318], requires_grad=True)], 'lr': 0.03721804511278195, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9922]], requires_grad=True)], 'lr': 0.003721804511278195, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6816]], requires_grad=True), Parameter containing:
# tensor([1.2131], requires_grad=True)], 'lr': 0.03759398496240601, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9948]], requires_grad=True)], 'lr': 0.0037593984962406013, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6847]], requires_grad=True), Parameter containing:
# tensor([1.1913], requires_grad=True)], 'lr': 0.03796992481203008, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9974]], requires_grad=True)], 'lr': 0.0037969924812030075, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6846]], requires_grad=True), Parameter containing:
# tensor([1.1829], requires_grad=True)], 'lr': 0.038345864661654135, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9979]], requires_grad=True)], 'lr': 0.003834586466165413, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6882]], requires_grad=True), Parameter containing:
# tensor([1.1970], requires_grad=True)], 'lr': 0.03872180451127819, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.9961]], requires_grad=True)], 'lr': 0.003872180451127819, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.6905]], requires_grad=True), Parameter containing:
# tensor([1.1805], requires_grad=True)], 'lr': 0.039097744360902256, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# ...
# tensor([[0.6012]], requires_grad=True)], 'lr': 0.00016348773841961872, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7994]], requires_grad=True), Parameter containing:
# tensor([0.4716], requires_grad=True)], 'lr': 0.0014986376021798422, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 0.0001498637602179842, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7995]], requires_grad=True), Parameter containing:
# tensor([0.4721], requires_grad=True)], 'lr': 0.0013623978201634968, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6011]], requires_grad=True)], 'lr': 0.00013623978201634967, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7996]], requires_grad=True), Parameter containing:
# tensor([0.4720], requires_grad=True)], 'lr': 0.0012261580381471406, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6011]], requires_grad=True)], 'lr': 0.00012261580381471405, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7994]], requires_grad=True), Parameter containing:
# tensor([0.4715], requires_grad=True)], 'lr': 0.0010899182561307952, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6012]], requires_grad=True)], 'lr': 0.00010899182561307952, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4716], requires_grad=True)], 'lr': 0.00095367847411445, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6012]], requires_grad=True)], 'lr': 9.5367847411445e-05, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4717], requires_grad=True)], 'lr': 0.0008174386920980937, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6012]], requires_grad=True)], 'lr': 8.174386920980936e-05, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4714], requires_grad=True)], 'lr': 0.0006811989100817484, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 6.811989100817484e-05, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4712], requires_grad=True)], 'lr': 0.0005449591280654031, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 5.4495912806540314e-05, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4709], requires_grad=True)], 'lr': 0.00040871934604904683, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 4.087193460490468e-05, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7994]], requires_grad=True), Parameter containing:
# tensor([0.4710], requires_grad=True)], 'lr': 0.00027247956403270157, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 2.7247956403270157e-05, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4710], requires_grad=True)], 'lr': 0.00013623978201635634, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 1.3623978201635634e-05, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4709], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4709], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4709], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4709], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4709], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4709], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4709], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4709], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4709], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4709], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4709], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4709], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4709], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4709], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4709], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4709], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4709], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4709], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4709], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4709], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4709], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4709], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4709], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4709], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]
# lr:  [{'params': [Parameter containing:
# tensor([[-0.7993]], requires_grad=True), Parameter containing:
# tensor([0.4709], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.1}, {'params': [Parameter containing:
# tensor([[0.6013]], requires_grad=True)], 'lr': 0.0, 'momentum': 0.0, 'dampening': 0, 'weight_decay': 0.0, 'nesterov': False, 'initial_lr': 0.01}]

# %%
ax = plt.subplot(1, 1, 1)
plt.scatter(new_X, emp_stand_noised, label='entire dataset', alpha=.75)
plt.scatter(x_trunc_norm, emp_stand_y_trunc, label='truncated dataset', alpha=.75)
plt.plot(norm_data, trunc_emp_stand_ols.predict(norm_data), color='r', label='ols')
plt.plot(norm_data, gt_emp_stand.predict(norm_data), color='green', label='gt')
plt.plot(norm_data, unknown_res(Tensor(norm_data)).detach().numpy(), label='unknown', color='blue')
plt.legend()
ax.set_title("Unknown Noise Variance - Normalized")
ax.set_xlabel("x")
ax.set_ylabel("y")
plt.show()

ax = plt.subplot(1, 1, 1)
plt.scatter(X, noised, label='entire dataset', alpha=.75)
plt.scatter(x_trunc, y_trunc, label='truncated dataset', alpha=.75)
plt.plot(unnorm_data, trunc_ols.predict(unnorm_data), label='ols', color='red')
plt.plot(unnorm_data, gt_ols.predict(unnorm_data), color='g', label='gt')
plt.plot(unnorm_data, (Tensor(unnorm_data)@unknown_weight_unnorm + unknown_bias_unnorm), color='blue', label='unknown')
plt.legend()
ax.set_title("Unknown Noise Variance - UnNormalized")
ax.set_xlabel("x")
ax.set_ylabel("y")
plt.show()

# %% [markdown]
# # Truncate at Zero and Run for High Variance

# %%
args.__setattr__('batch_size', 25)
args.__setattr__('steps', 1000)
args.__setattr__('step_lr', 10)
args.__setattr__('step_lr_gamma', .9)
args.__setattr__('tol', 1e-2)
args.__setattr__('trials', 3)
args.__setattr__('var_lr', 1e-1)

# %%
# expriment parameters
w_lower, w_upper = -1, 1
d, k = 20, 1

for i in range(args.trials):
    # create store and add table
    store = Store(OUT_DIR)
    store.add_table(TABLE_NAME, { 
        'ols_r2': float,
        'ols_param_mse': float,
        'ols_var_mse': float,
        'known_emp_r2': float,
        'known_emp_param_mse': float,
        'known_emp_time': int,
        'known_r2': float,
        'known_param_mse': float,
        'known_time': int,
        'unknown_r2': float, 
        'unknown_param_mse': float,
        'unknown_var_mse': float,
        'unknown_time': int,
        'alpha': float, 
        'num_samples': int,
        'noise_scale': float, 
    })

    # distribution for generating feature vectors
    w = Uniform(w_lower, w_upper)
    dist = MultivariateNormal(ch.zeros(d), ch.eye(d)/d)
    phi = Left(Tensor([0.0]))
    
    # generate ground truth
    gt = ch.nn.Linear(in_features=d, out_features=k)
    gt.weight = ch.nn.Parameter(w.sample(ch.Size([k, d])))
    gt.bias = ch.nn.Parameter(w.sample(ch.Size([1, 1]))) if args.bias else None
    
    # create base classifier
    with ch.no_grad():
        # generate data
        X = dist.sample(ch.Size([args.samples]))
        y = gt(X)
        rand_noise = ch.randn(X.size(0), 1)
        
    for noise_var in range(1, 21): 
        noise_var = Tensor([noise_var])[None,...]
        # add noise to ground-truth pedictions
        noised = y + ch.sqrt(noise_var)*rand_noise
        # truncate based off of the standardized data
        indices = phi(noised).nonzero(as_tuple=False).flatten()
        y_trunc, x_trunc = noised[indices], X[indices]
        alpha = Tensor([y_trunc.size(0) / args.samples])
        
        # normalize x features so that ||x_{i}||_{2}^{2} <= 1
        l_inf = LA.norm(x_trunc, dim=-1, ord=float('inf')).max() # find max l_inf
        # calculate normalizing constant
        beta = l_inf*math.sqrt(x_trunc.size(1))
        """
        Divide input features by normalizing constant. By doing so, 
        the weights will be increased by a magnitude of beta.
        """
        x_trunc_norm = x_trunc / beta
         # normalize entire dataset by beta
        x_norm = X / beta
        
        # ground-truth ols
        gt_ols = LinearRegression()
        gt_ols.fit(X, noised)
        gt_params = ch.cat([Tensor(gt_ols.coef_).T, Tensor(gt_ols.intercept_)[..., None]]).flatten()
        print("gt params: ", gt_params)
        print("gt var: ", noise_var)
        
        # empirical linear regression
        ols = LinearRegression() 
        ols.fit(x_trunc, y_trunc)
        ols_var = ch.var(Tensor(ols.predict(x_trunc)) - y_trunc, dim=0)[..., None]
        print("ols var", ols_var)
        ols_params = ch.cat([Tensor(ols.coef_).T, Tensor(ols.intercept_)[..., None]]).flatten()
        print("ols params: ", ols_params)
        # check r2 for entire dataset
        ols_pred = ols.predict(X)
        print('ols_param_mse', mse_loss(ols_params, gt_params))
        print('ols_var_mse', mse_loss(ols_var, noise_var))

        # ols results
        store[TABLE_NAME].update_row({
            'ols_r2': r2_score(noised.flatten(), ols_pred.flatten()), 
            'ols_param_mse': mse_loss(ols_params, gt_params),
            'ols_var_mse': mse_loss(ols_var, noise_var), 
        })
        
        """
        Run dataset on truncated regression with known variance, while 
        assuming that the empirical noise variance is the underlying noise 
        variance of our linear regression. This means that we want to standardize 
        our dependent variable by the empirical noise variance. 
        """
        # variance of the residuals
        emp_noise_var = (y_trunc - ols.predict(x_trunc_norm)).var(0)
        # standardize y trunc by the empirical noise variance
        emp_stand_y_trunc = y_trunc / ch.sqrt(emp_noise_var)
        # standardize noised by the empirical noise variance
        emp_stand_noised = noised / ch.sqrt(emp_noise_var)
        
        trunc_reg = TruncatedRegression(phi=phi, alpha=alpha, args=args, bias=args.bias, var=ch.ones(1))
        st = datetime.datetime.now()
        known_emp_results = trunc_reg.fit(x_trunc_norm, emp_stand_y_trunc)
        w, w0 = (known_emp_results.weight.detach().cpu() * ch.sqrt(emp_noise_var)) / beta, known_emp_results.bias.detach().cpu()[..., None] * ch.sqrt(emp_noise_var)
        known_emp_params = ch.cat([w, w0], dim=1).flatten()
        # known emp results
        store[TABLE_NAME].update_row({
            'known_emp_r2': r2_score(noised.flatten(), X@w.T + w0), 
            'known_emp_param_mse': mse_loss(known_emp_params, gt_params),
            'known_emp_time': int((datetime.datetime.now() - st).total_seconds()), 
        })
        
        """
        Run dataset on truncated regression with known variance. This means that we want to standardize 
        our dependent variable by the true noise variance. 
        """
        # standardize y trunc by the empirical noise variance
        stand_y_trunc = y_trunc / math.sqrt(noise_var)
        # standardize noised by the empirical noise variance
        stand_noised = noised / math.sqrt(noise_var)
        trunc_reg = TruncatedRegression(phi=phi, alpha=alpha, args=args, bias=args.bias, var=ch.ones(1))
        st = datetime.datetime.now()
        known_results = trunc_reg.fit(x_trunc_norm, stand_y_trunc)
        w, w0 = (known_results.weight.detach().cpu() * ch.sqrt(noise_var)) / beta, known_results.bias.detach().cpu()[..., None] * ch.sqrt(noise_var)
        known_params = ch.cat([w, w0], dim=1).flatten()
        # known results
        store[TABLE_NAME].update_row({
            'known_r2': r2_score(noised.flatten(), X@w.T + w0), 
            'known_param_mse': mse_loss(known_params, gt_params),
            'known_time': int((datetime.datetime.now() - st).total_seconds()), 
        })
        
        print("known weight grad: ", known_results.weight.grad)
        print("known bias grad: ", known_results.bias.grad)
        
        # truncated regression with unknown variance
        args.__setattr__('batch_size', 25)
        trunc_reg = TruncatedRegression(phi=phi, alpha=alpha, args=args, bias=args.bias)
        st = datetime.datetime.now()
#         unknown_results = trunc_reg.fit(x_trunc_norm, emp_stand_y_trunc)
        unknown_results = trunc_reg.fit(x_trunc_norm, y_trunc)

#         var_ = unknown_results.lambda_.inverse()
        unknown_var = unknown_results.lambda_.inverse()

#         unknown_var = var_ * ch.sqrt(emp_noise_var)
#         w, w0 = (((unknown_results.weight * var_) * ch.sqrt(emp_noise_var)) / beta).detach(), ((unknown_results.bias * var_) * ch.sqrt(emp_noise_var)).detach()
        w, w0 = ((unknown_results.weight * unknown_var) / beta).detach(), (unknown_results.bias * unknown_var * ch.sqrt(emp_noise_var)).detach()

        unknown_params = ch.cat([w, w0], dim=1).flatten()
        
        print("unknown var: ", unknown_var)
        print("unknown params: ", unknown_params)
        print("weight grad: ", unknown_results.weight.grad)
        print("bias grad: ", unknown_results.bias.grad)
        print("lambda grad: ", unknown_results.lambda_.grad)

        # known emp results
        store[TABLE_NAME].update_row({
            'unknown_r2': r2_score(noised.flatten(), X@w.T + w0), 
            'unknown_param_mse': mse_loss(unknown_params, gt_params),
            'unknown_var_mse': mse_loss(unknown_var, noise_var),
            'unknown_time': int((datetime.datetime.now() - st).total_seconds()), 
        })
        
        
        # add additional exp data to store
        store[TABLE_NAME].update_row({ 
            'alpha': float(alpha.flatten()),
            'num_samples': x_trunc.size(0),
            'noise_scale': noise_var, 
        })

        # append row to table
        store[TABLE_NAME].flush_row()
    store.close()
# Out:
# Logging in: /home/gridsan/stefanou/Regression/NoScale/185ae5bb-0571-41f8-b669-83e8d95a4e27
# gt params:  tensor([ 0.8767,  0.4377, -0.1562, -0.1915,  0.1332,  0.0272, -0.9689,  0.7730,
#         -0.7124, -0.1744, -0.1592,  0.4645, -0.1735,  0.1258,  1.0638,  0.2132,
#          0.1462,  0.6746,  0.5671,  0.7071, -0.9600])
# gt var:  tensor([[1.]])
# ols var tensor([[0.2234]])
# ols params:  tensor([ 0.2103,  0.0472, -0.2996, -0.0881, -0.1596,  0.0991, -0.1764,  0.0599,
#         -0.1249, -0.1187, -0.0583,  0.2237, -0.2381,  0.0018,  0.2094, -0.0430,
#          0.0453,  0.2951, -0.0418,  0.0122,  0.5986])
# ols_param_mse tensor(0.3107)
# ols_var_mse tensor(0.6030)
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# known weight grad:  tensor([[-6.5523e-03, -1.4248e-03, -4.4063e-03,  7.3965e-03,  9.0610e-03,
#           1.0837e-02,  7.9320e-03,  3.6671e-03,  6.1020e-03,  1.0271e-05,
#          -1.2740e-03, -2.6533e-03, -3.7909e-03,  4.0200e-03, -1.4007e-02,
#          -9.9523e-03, -7.8410e-03, -9.2322e-03,  9.4696e-04,  8.7384e-03]])
# known bias grad:  tensor([-0.1099])
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# unknown var:  tensor([[0.2824]], grad_fn=<InverseBackward>)
# unknown params:  tensor([ 0.2658,  0.0601, -0.3828, -0.1116, -0.2053,  0.1259, -0.2235,  0.0737,
#         -0.1577, -0.1511, -0.0750,  0.2856, -0.3036,  0.0017,  0.2649, -0.0560,
#          0.0594,  0.3754, -0.0546,  0.0138,  0.2068])
# weight grad:  tensor([[ 0.0098, -0.0011, -0.0064,  0.0023,  0.0041, -0.0048,  0.0011, -0.0065,
#          -0.0100, -0.0024, -0.0053, -0.0064, -0.0058, -0.0009,  0.0083, -0.0046,
#           0.0003, -0.0014, -0.0008,  0.0038]])
# bias grad:  tensor([0.0522])
# lambda grad:  tensor([[-0.0581]])
# gt params:  tensor([ 0.9677,  0.3090, -0.1600, -0.2650,  0.0711,  0.0829, -1.0176,  0.7151,
#         -0.7943, -0.1432, -0.1094,  0.4596, -0.2299,  0.0693,  1.1119,  0.2827,
#          0.2214,  0.6874,  0.4819,  0.7674, -0.9734])
# gt var:  tensor([[2.]])
# ols var tensor([[0.4921]])
# ols params:  tensor([ 0.2322,  0.1076, -0.3311, -0.0476, -0.2555,  0.4420, -0.2102,  0.0742,
#         -0.2985, -0.0306, -0.2135,  0.3454, -0.2557, -0.0336,  0.1380, -0.0516,
#         -0.0366,  0.5549,  0.0464, -0.1272,  0.9268])
# ols_param_mse tensor(0.3807)
# ols_var_mse tensor(2.2737)
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# known weight grad:  tensor([[-0.0011,  0.0030,  0.0013,  0.0015, -0.0005, -0.0005, -0.0008,  0.0013,
#           0.0038,  0.0009, -0.0002,  0.0024, -0.0008,  0.0017, -0.0039, -0.0001,
#           0.0026,  0.0018, -0.0019, -0.0014]])
# known bias grad:  tensor([-0.0447])
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# unknown var:  tensor([[0.9406]], grad_fn=<InverseBackward>)
# unknown params:  tensor([ 0.4434,  0.2001, -0.6342, -0.0950, -0.4910,  0.8704, -0.4038,  0.1351,
#         -0.5679, -0.0522, -0.4120,  0.6613, -0.4931, -0.0662,  0.2594, -0.0954,
#         -0.0723,  1.0756,  0.0765, -0.2580,  0.2296])
# weight grad:  tensor([[ 0.0080, -0.0392,  0.0240, -0.0195, -0.0002, -0.0130,  0.0580,  0.0212,
#          -0.0448, -0.0106, -0.0142, -0.0266,  0.0014, -0.0024,  0.0148,  0.0042,
#           0.0371, -0.0007,  0.0089,  0.0052]])
# bias grad:  tensor([0.3812])
# lambda grad:  tensor([[-0.3753]])
# gt params:  tensor([ 1.0374,  0.2103, -0.1630, -0.3215,  0.0235,  0.1255, -1.0550,  0.6707,
#         -0.8571, -0.1192, -0.0712,  0.4558, -0.2731,  0.0259,  1.1488,  0.3359,
#          0.2792,  0.6971,  0.4165,  0.8136, -0.9836])
# gt var:  tensor([[3.]])
# ols var tensor([[0.7978]])
# ols params:  tensor([ 0.1925,  0.1312, -0.3558, -0.1059, -0.2563,  0.3340, -0.3066,  0.0498,
#         -0.3129, -0.0966, -0.2605,  0.2477, -0.3477,  0.0505,  0.3070, -0.1185,
#         -0.0861,  0.5909, -0.0056,  0.0269,  1.1620])
# ols_param_mse tensor(0.4149)
# ols_var_mse tensor(4.8495)
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# known weight grad:  tensor([[ 0.0050, -0.0060,  0.0093,  0.0051, -0.0075, -0.0045,  0.0104,  0.0039,
#           0.0130, -0.0075,  0.0049, -0.0049,  0.0002, -0.0093,  0.0007, -0.0009,
#           0.0112, -0.0104, -0.0112,  0.0012]])
# known bias grad:  tensor([-0.0871])
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# unknown var:  tensor([[1.8124]], grad_fn=<InverseBackward>)
# unknown params:  tensor([ 0.4259,  0.2993, -0.8170, -0.2363, -0.5960,  0.7746, -0.6994,  0.1163,
#         -0.7070, -0.2222, -0.6007,  0.5732, -0.8006,  0.1125,  0.7062, -0.2777,
#         -0.2001,  1.3642, -0.0120,  0.0497,  0.0097])
# weight grad:  tensor([[-0.0132, -0.0102,  0.0129, -0.0203, -0.0100,  0.0036,  0.0203,  0.0466,
#           0.0060, -0.0155, -0.0066, -0.0050, -0.0107, -0.0209,  0.0171,  0.0451,
#          -0.0105,  0.0128,  0.0120, -0.0448]])
# bias grad:  tensor([0.4217])
# lambda grad:  tensor([[-0.4892]])
# gt params:  tensor([ 1.0963,  0.1271, -0.1655, -0.3691, -0.0167,  0.1615, -1.0866,  0.6332,
#         -0.9101, -0.0989, -0.0389,  0.4526, -0.3095, -0.0106,  1.1799,  0.3808,
#          0.3279,  0.7053,  0.3614,  0.8526, -0.9923])
# gt var:  tensor([[4.]])
# ols var tensor([[1.1201]])
# ols params:  tensor([ 0.1781,  0.2330, -0.3048, -0.3088, -0.3549,  0.3840, -0.2084,  0.0161,
#         -0.3493,  0.0331, -0.1375,  0.0194, -0.5766,  0.0605,  0.3440, -0.1112,
#         -0.1834,  0.5845,  0.1011,  0.0369,  1.3461])
# ols_param_mse tensor(0.4865)
# ols_var_mse tensor(8.2939)
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# known weight grad:  tensor([[-0.0171, -0.0113, -0.0028, -0.0012, -0.0112,  0.0004,  0.0105, -0.0032,
#           0.0231,  0.0047, -0.0126, -0.0102,  0.0191, -0.0065, -0.0269, -0.0157,
#          -0.0014,  0.0159, -0.0003,  0.0061]])
# known bias grad:  tensor([-0.1755])
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# unknown var:  tensor([[2.4255]], grad_fn=<InverseBackward>)
# unknown params:  tensor([ 0.3841,  0.5145, -0.6746, -0.6718, -0.7839,  0.8433, -0.4511,  0.0348,
#         -0.7605,  0.0787, -0.3074,  0.0389, -1.2623,  0.1287,  0.7499, -0.2520,
#         -0.4059,  1.2823,  0.2236,  0.0745, -0.0855])
# weight grad:  tensor([[ 0.0087,  0.0018, -0.0076, -0.0033,  0.0043,  0.0043,  0.0192, -0.0140,
#           0.0185,  0.0204,  0.0304,  0.0262,  0.0051,  0.0062,  0.0080,  0.0046,
#           0.0225,  0.0115,  0.0092, -0.0108]])
# bias grad:  tensor([0.1034])
# lambda grad:  tensor([[-0.2710]])
# gt params:  tensor([ 1.1481,  0.0538, -0.1678, -0.4110, -0.0521,  0.1932, -1.1143,  0.6002,
#         -0.9568, -0.0811, -0.0105,  0.4498, -0.3416, -0.0429,  1.2074,  0.4204,
#          0.3707,  0.7126,  0.3128,  0.8869, -0.9999])
# gt var:  tensor([[5.]])
# ols var tensor([[1.4323]])
# ols params:  tensor([ 0.1421,  0.2245, -0.3089, -0.3403, -0.4057,  0.4530, -0.1110, -0.0626,
#         -0.3106,  0.0054,  0.0254,  0.0963, -0.6359,  0.2248,  0.4888,  0.0059,
#         -0.1407,  0.6395, -0.0027, -0.0342,  1.5357])
# ols_param_mse tensor(0.5594)
# ols_var_mse tensor(12.7283)
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# known weight grad:  tensor([[-0.0059,  0.0017, -0.0058,  0.0033, -0.0030,  0.0073, -0.0007, -0.0048,
#          -0.0004, -0.0148,  0.0006, -0.0108,  0.0101, -0.0077,  0.0072,  0.0018,
#           0.0072, -0.0009, -0.0152,  0.0020]])
# known bias grad:  tensor([-0.1335])
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# unknown var:  tensor([[3.2134]], grad_fn=<InverseBackward>)
# unknown params:  tensor([ 0.8642,  0.8910, -0.9297, -0.8942, -0.9425,  0.9375, -0.8394, -0.8200,
#         -0.8960,  0.8134,  0.7673,  0.8110, -0.9680,  0.8792,  0.9359,  0.7693,
#         -0.8263,  1.0106,  0.6389, -0.8598,  0.2767])
# weight grad:  tensor([[ 0.0308,  0.0157,  0.0514, -0.0539,  0.0422, -0.0244, -0.0043, -0.0135,
#          -0.0192,  0.0367,  0.0062,  0.0071,  0.0593, -0.0062,  0.0234, -0.0066,
#          -0.0212, -0.0396, -0.0050,  0.0126]])
# bias grad:  tensor([0.6847])
# lambda grad:  tensor([[-1.0814]])
# gt params:  tensor([ 1.1950, -0.0125, -0.1698, -0.4490, -0.0841,  0.2219, -1.1395,  0.5704,
#         -0.9990, -0.0650,  0.0152,  0.4472, -0.3706, -0.0720,  1.2321,  0.4562,
#          0.4095,  0.7191,  0.2689,  0.9180, -1.0068])
# gt var:  tensor([[6.]])
# ols var tensor([[1.7584]])
# ols params:  tensor([ 2.1023e-01,  2.2482e-01, -2.8910e-01, -3.8190e-01, -4.5660e-01,
#          6.3733e-01, -1.6104e-01,  7.1507e-03, -3.8975e-01,  8.1355e-04,
#         -7.5227e-03,  8.9527e-02, -6.5594e-01,  2.5819e-01,  4.5122e-01,
#          7.6034e-02, -5.1205e-02,  6.6430e-01, -6.5120e-02,  1.6120e-01,
#          1.6702e+00])
# ols_param_mse tensor(0.5784)
# ols_var_mse tensor(17.9915)
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# known weight grad:  tensor([[ 0.0020, -0.0110, -0.0046, -0.0125,  0.0074,  0.0076, -0.0117,  0.0094,
#           0.0145,  0.0030,  0.0014, -0.0040,  0.0015,  0.0012,  0.0013,  0.0025,
#           0.0004,  0.0080,  0.0088, -0.0041]])
# known bias grad:  tensor([0.1232])
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# unknown var:  tensor([[5.1378]], grad_fn=<InverseBackward>)
# unknown params:  tensor([ 0.7611,  0.8357, -1.0568, -1.3843, -1.6876,  2.3804, -0.6020,  0.0094,
#         -1.4614,  0.0142, -0.0400,  0.3160, -2.4175,  0.9506,  1.6557,  0.2369,
#         -0.1735,  2.4384, -0.2480,  0.5726, -0.2692])
# weight grad:  tensor([[-0.0072, -0.0009, -0.0022,  0.0155,  0.0028,  0.0050, -0.0119,  0.0215,
#           0.0410,  0.0013,  0.0095,  0.0303, -0.0080,  0.0186, -0.0085, -0.0161,
#           0.0094, -0.0055,  0.0062, -0.0056]])
# bias grad:  tensor([0.0643])
# lambda grad:  tensor([[-0.5252]])
# gt params:  tensor([ 1.2380, -0.0734, -0.1716, -0.4838, -0.1135,  0.2482, -1.1626,  0.5429,
#         -1.0378, -0.0501,  0.0388,  0.4449, -0.3973, -0.0988,  1.2549,  0.4891,
#          0.4452,  0.7252,  0.2285,  0.9465, -1.0132])
# gt var:  tensor([[7.]])
# ols var tensor([[2.0818]])
# ols params:  tensor([ 0.3031,  0.1462, -0.1922, -0.5762, -0.4968,  0.6580, -0.2018,  0.1977,
#         -0.5071,  0.1662,  0.1220,  0.1079, -0.5687,  0.3669,  0.4554, -0.0583,
#         -0.1356,  0.5961, -0.1357,  0.1483,  1.8044])
# ols_param_mse tensor(0.6183)
# ols_var_mse tensor(24.1890)
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# known weight grad:  tensor([[ 0.0117, -0.0079,  0.0015, -0.0043, -0.0207, -0.0087, -0.0233,  0.0036,
#          -0.0047,  0.0013,  0.0229,  0.0248,  0.0286, -0.0144, -0.0086, -0.0024,
#          -0.0052,  0.0153, -0.0070,  0.0190]])
# known bias grad:  tensor([0.0580])
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# unknown var:  tensor([[6.5666]], grad_fn=<InverseBackward>)
# unknown params:  tensor([ 0.8658,  0.7658, -0.7123, -0.9250, -0.8524,  0.9808, -0.7835,  0.7386,
#         -0.9169,  0.8149,  0.7218,  0.7157, -0.9068,  0.8682,  0.9179, -0.7180,
#         -0.6835,  0.9716, -0.7155,  0.7105, -1.0859])
# weight grad:  tensor([[ 0.0552,  0.0266,  0.0004, -0.0332, -0.0296,  0.0072,  0.0148,  0.0127,
#          -0.0342,  0.0540,  0.0051, -0.0064,  0.0063,  0.0213, -0.0060,  0.0088,
#          -0.0052, -0.0041,  0.0410,  0.0237]])
# bias grad:  tensor([0.0705])
# lambda grad:  tensor([[-0.2927]])
# ...
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# unknown var:  tensor([[10.9017]], grad_fn=<InverseBackward>)
# unknown params:  tensor([-0.4337,  0.2805, -0.3662, -0.4078,  0.2425, -0.4097,  0.2843,  0.3100,
#          0.2961, -0.3846,  0.2934,  0.3031, -0.4727, -0.3977,  0.2604, -0.4185,
#         -0.4233, -0.3869, -0.4033, -0.3484,  4.3856])
# weight grad:  tensor([[-0.0063, -0.0142, -0.0302,  0.0147, -0.0657,  0.0298,  0.0043,  0.0014,
#          -0.0544,  0.0351,  0.0201,  0.0677,  0.0828,  0.0426,  0.0273,  0.0601,
#          -0.0154,  0.0122, -0.0041,  0.0054]])
# bias grad:  tensor([0.6776])
# lambda grad:  tensor([[-3.1366]])
# gt params:  tensor([-1.9560,  0.7707,  1.2953, -1.3614, -0.4750, -1.3425, -0.3535,  1.7565,
#          0.2971,  1.2332, -0.2059, -0.2043, -2.3571,  0.1402, -0.2100, -0.2237,
#         -0.1207,  0.5472, -0.4112,  0.5888,  0.2194])
# gt var:  tensor([[18.]])
# ols var tensor([[6.4211]])
# ols params:  tensor([-0.9478, -0.2895,  0.4712, -0.3508, -0.8438, -0.5608, -0.2913,  0.4359,
#         -0.5372,  0.3416, -0.2981, -0.2488, -1.6099, -0.0218, -0.8619, -0.4973,
#         -0.6932,  0.1885, -0.1845,  0.7511,  3.3173])
# ols_param_mse tensor(0.9073)
# ols_var_mse tensor(134.0703)
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# known weight grad:  tensor([[ 0.0121,  0.0028,  0.0055,  0.0214, -0.0055, -0.0087, -0.0059, -0.0176,
#          -0.0059,  0.0174,  0.0025,  0.0091, -0.0017,  0.0068,  0.0157, -0.0005,
#          -0.0039,  0.0114, -0.0107, -0.0034]])
# known bias grad:  tensor([0.1207])
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# unknown var:  tensor([[9.3695]], grad_fn=<InverseBackward>)
# unknown params:  tensor([-0.6544, -0.6517,  0.5122, -0.6509, -0.6540, -0.6524, -0.6522,  0.5114,
#         -0.6517,  0.5128, -0.6510, -0.6515, -0.6558, -0.2634, -0.6538, -0.6516,
#         -0.6522,  0.5111, -0.6515,  0.5141,  6.0734])
# weight grad:  tensor([[-0.0768, -0.0746,  0.0137, -0.0016,  0.0391,  0.0048, -0.0563,  0.0067,
#          -0.0071, -0.0157, -0.0337, -0.0431,  0.0311,  0.0120, -0.0178, -0.0368,
#           0.0431, -0.0357, -0.0643,  0.0229]])
# bias grad:  tensor([1.7827])
# lambda grad:  tensor([[-7.9499]])
# gt params:  tensor([-1.9896,  0.7789,  1.3122, -1.3872, -0.4659, -1.3542, -0.3561,  1.7866,
#          0.2879,  1.2500, -0.2048, -0.1926, -2.4009,  0.1176, -0.2217, -0.2392,
#         -0.1412,  0.5633, -0.3999,  0.5879,  0.2175])
# gt var:  tensor([[19.]])
# ols var tensor([[6.7779]])
# ols params:  tensor([-0.9538, -0.3103,  0.4654, -0.3490, -0.8448, -0.5511, -0.2922,  0.4298,
#         -0.5693,  0.3339, -0.2994, -0.2382, -1.6332, -0.0487, -0.8914, -0.5203,
#         -0.7294,  0.1948, -0.1669,  0.7546,  3.4003])
# ols_param_mse tensor(0.9577)
# ols_var_mse tensor(149.3807)
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# known weight grad:  tensor([[-0.0072, -0.0094,  0.0022,  0.0076, -0.0085,  0.0221, -0.0009,  0.0084,
#          -0.0032, -0.0104,  0.0123, -0.0152,  0.0337, -0.0194, -0.0050,  0.0018,
#          -0.0240, -0.0074,  0.0173,  0.0027]])
# known bias grad:  tensor([-0.2467])
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# unknown var:  tensor([[6.2969]], grad_fn=<InverseBackward>)
# unknown params:  tensor([-0.6939,  0.4996,  0.5232, -0.6924, -0.7029, -0.6821,  0.5047,  0.5351,
#         -0.6744, -0.6451, -0.6854, -0.6696, -0.7256, -0.6771, -0.7152,  0.5091,
#          0.5206, -0.6529,  0.4989, -0.6245,  8.6495])
# weight grad:  tensor([[-0.1226, -0.0165, -0.0824, -0.1566, -0.0055, -0.0137, -0.0074,  0.1117,
#           0.0409,  0.0309,  0.0674,  0.0721,  0.0521, -0.0810,  0.1521, -0.0725,
#          -0.0638,  0.0773,  0.0676, -0.0407]])
# bias grad:  tensor([-0.2747])
# lambda grad:  tensor([[7.2048]])
# gt params:  tensor([-2.0224,  0.7869,  1.3286, -1.4124, -0.4570, -1.3656, -0.3587,  1.8160,
#          0.2789,  1.2663, -0.2036, -0.1811, -2.4435,  0.0957, -0.2331, -0.2542,
#         -0.1612,  0.5790, -0.3889,  0.5869,  0.2157])
# gt var:  tensor([[20.]])
# ols var tensor([[7.1346]])
# ols params:  tensor([-0.9597, -0.3305,  0.4599, -0.3472, -0.8458, -0.5416, -0.2931,  0.4239,
#         -0.6005,  0.3265, -0.3007, -0.2279, -1.6559, -0.0750, -0.9201, -0.5427,
#         -0.7647,  0.2009, -0.1499,  0.7580,  3.4812])
# ols_param_mse tensor(1.0081)
# ols_var_mse tensor(165.5188)
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# known weight grad:  tensor([[ 0.0016,  0.0059,  0.0007,  0.0019, -0.0031, -0.0018,  0.0150,  0.0136,
#           0.0038,  0.0025,  0.0102,  0.0149,  0.0125,  0.0167, -0.0097,  0.0098,
#          -0.0125, -0.0052,  0.0039, -0.0196]])
# known bias grad:  tensor([0.1853])
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# unknown var:  tensor([[11.6496]], grad_fn=<InverseBackward>)
# unknown params:  tensor([-0.4761, -0.4393,  0.5012,  0.3969, -0.4862, -0.3779, -0.3884, -0.3605,
#         -0.3662,  0.4839, -0.4552, -0.3795, -0.5231, -0.3248, -0.4281,  0.3975,
#          0.4277,  0.4848, -0.4005,  0.5353,  5.8210])
# weight grad:  tensor([[ 0.0144,  0.0292, -0.0390, -0.0675, -0.0297,  0.0142, -0.0174,  0.0613,
#          -0.0209,  0.0620,  0.0345,  0.0468,  0.0484, -0.0411, -0.0163,  0.0106,
#           0.0018, -0.0840,  0.0025, -0.0289]])
# bias grad:  tensor([0.8347])
# lambda grad:  tensor([[-3.8514]])

# %%
reader = CollectionReader(OUT_DIR)
logs = reader.df(TABLE_NAME)
reader.close()
logs.head()
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 127.36it/s]
#      ols_r2  ols_param_mse  ols_var_mse  known_emp_r2  known_emp_param_mse  \
# 0 -1.861840       0.310655     0.603031     -1.609516             0.295525
# 1 -1.563572       0.380712     2.273743     -1.255578             0.348148
# 2 -1.372259       0.414942     4.849494     -1.066571             0.367160
# 3 -1.248708       0.486533     8.293891     -0.918610             0.419355
# 4 -1.194109       0.559366    12.728254     -0.876338             0.479240
#
#    known_emp_time  known_r2  known_param_mse  known_time  unknown_r2  \
# 0               9 -0.150212         0.209119           4   -1.006172
# 1               1 -0.067630         0.221062           3   -0.616519
# 2               1 -0.013484         0.204753           3   -0.272589
# 3               2  0.004100         0.232205           3   -0.177233
# 4               2  0.003520         0.259947           2   -0.359718
#
#    unknown_param_mse  unknown_var_mse  unknown_time  alpha  num_samples  \
# 0           0.245644         0.514977            42  0.196          196
# 1           0.297083         1.122427            33  0.251          251
# 2           0.269989         1.410409            18  0.283          283
# 3           0.331003         2.479014             7  0.313          313
# 4           0.681945         3.192079            28  0.328          328
#
#    noise_scale                                exp_id
# 0          1.0  185ae5bb-0571-41f8-b669-83e8d95a4e27
# 1          2.0  185ae5bb-0571-41f8-b669-83e8d95a4e27
# 2          3.0  185ae5bb-0571-41f8-b669-83e8d95a4e27
# 3          4.0  185ae5bb-0571-41f8-b669-83e8d95a4e27
# 4          5.0  185ae5bb-0571-41f8-b669-83e8d95a4e27

# %%
logs[['noise_scale', 'unknown_var_mse', 'unknown_param_mse', 'num_samples', 'unknown_time']]
# Out:
#     noise_scale  unknown_var_mse  unknown_param_mse  num_samples  unknown_time
# 0           1.0         0.514977           0.245644          196            42
# 1           2.0         1.122427           0.297083          251            33
# 2           3.0         1.410409           0.269989          283            18
# 3           4.0         2.479014           0.331003          313             7
# 4           5.0         3.192079           0.681945          328            28
# 5           6.0         0.743354           0.968214          344            12
# 6           7.0         0.187851           0.426150          356            26
# 7           8.0         0.436223           0.296897          369            27
# 8           9.0         7.131388           0.688393          373            27
# 9          10.0        53.092472           1.547719          376            25
# 10         11.0        15.581944           0.994738          381            25
# 11         12.0         5.044102           0.445675          386            25
# 12         13.0         5.444358           0.388430          390            25
# 13         14.0        16.247478           0.603543          393            25
# 14         15.0        36.404099           1.218531          397            26
# 15         16.0        67.804276           1.747727          399            26
# 16         17.0        64.915649           1.698440          404            24
# 17         18.0        27.727249           0.985467          407            25
# 18         19.0       182.559433           4.415642          409            25
# 19         20.0        39.458920           1.242226          410            25
# 0           1.0         0.042896           0.045877          603            15
# 1           2.0         0.165968           0.095214          584             8
# 2           3.0         0.199096           0.181559          571            14
# 3           4.0         0.398052           0.666479          565             7
# 4           5.0         2.686117           0.594056          559            19
# 5           6.0        15.722461           0.676211          552            23
# 6           7.0         0.620405           0.470694          548            24
# 7           8.0         1.136785           0.479299          547            23
# 8           9.0         5.624022           0.612189          544            22
# 9          10.0         3.009923           0.736998          544            23
# 10         11.0         7.435303           0.635559          540            23
# 11         12.0        15.239357           0.995218          536            22
# 12         13.0        17.985905           1.250636          534            23
# 13         14.0        26.277483           1.053069          536            23
# 14         15.0        35.973854           1.524725          535            24
# 15         16.0        40.540348           1.678811          533            23
# 16         17.0        37.189693           1.714027          532            23
# 17         18.0        74.484856           2.231104          531            22
# 18         19.0       161.367615           4.294654          531            23
# 19         20.0        69.728416           2.419224          531            23
# 0           1.0         0.087329           0.074566          602            18
# 1           2.0         0.177253           0.141396          582            16
# 2           3.0         0.855530           0.217240          565             6
# 3           4.0         2.100117           0.632806          558            12
# 4           5.0         2.951411           0.486059          556            21
# 5           6.0         2.303893           0.557342          554            21
# 6           7.0         0.826300           2.321995          549             2
# 7           8.0         5.514291           0.487404          546            22
# 8           9.0         4.730026           0.682599          544            23
# 9          10.0        11.457355           0.886029          542            23
# 10         11.0        12.139603           0.877501          541            22
# 11         12.0        21.893963           1.220101          538            22
# 12         13.0        21.460213           1.271618          538            22
# 13         14.0        19.324648           1.159852          539            22
# 14         15.0        23.446949           1.421107          538            23
# 15         16.0        78.432922           2.717524          536            23
# 16         17.0        87.313759           2.734936          536            24
# 17         18.0        61.157288           2.314570          534            23
# 18         19.0        85.826782           3.107624          533            22
# 19         20.0        68.279617           2.667376          533            22

# %%
sns.lineplot(data=logs, x='noise_scale', y='ols_param_mse', label='ols')
sns.lineplot(data=logs, x='noise_scale', y='known_emp_param_mse', label='known emp')
sns.lineplot(data=logs, x='noise_scale', y='known_param_mse', label='known')
ax = sns.lineplot(data=logs, x='noise_scale', y='unknown_param_mse', label='unknown')
ax.set(xlabel='noise_scale', ylabel='L2 Distance to Ground-Truth')
plt.show()

sns.lineplot(data=logs, x='noise_scale', y='ols_var_mse', label='ols')
ax = sns.lineplot(data=logs, x='noise_scale', y='unknown_var_mse', label='unknown')
ax.set(xlabel='noise_scale', ylabel='L2 Distance to Ground-Truth')
# Out:
# [Text(0.5, 0, 'noise_scale'), Text(0, 0.5, 'L2 Distance to Ground-Truth')]

# %%
res.lambda_.inverse()
# Out:
# tensor([[2.9077]], grad_fn=<InverseBackward>)

# %%
dist.sample(ch.Size([100])).norm(dim=-1)
# Out:
# tensor([0.6903, 0.9780, 0.9607, 0.9691, 0.8257, 1.0464, 1.0696, 0.9103, 0.9877,
#         1.0978, 1.0124, 1.1689, 1.0996, 0.9948, 0.9516, 0.9487, 1.0618, 1.0187,
#         0.8520, 1.1182, 0.9272, 0.7540, 0.9260, 0.9004, 1.0651, 0.9687, 1.1002,
#         1.0299, 1.0563, 1.0269, 0.7774, 1.0002, 0.8786, 1.0422, 1.0883, 0.7597,
#         0.9271, 0.9221, 1.0873, 1.2425, 0.9307, 0.8321, 1.0668, 0.8805, 0.9663,
#         0.8169, 0.9059, 0.8257, 0.9709, 0.8491, 1.1537, 0.9127, 0.9482, 1.1934,
#         0.7890, 0.9207, 0.8007, 1.2793, 1.2047, 1.0478, 0.5766, 0.8797, 1.0624,
#         1.0752, 0.8503, 1.0313, 1.0230, 1.0546, 0.9953, 1.0530, 1.0762, 1.1761,
#         0.9407, 1.1177, 0.9512, 0.9430, 1.0217, 0.8608, 1.1675, 0.8071, 0.9953,
#         1.1789, 0.9102, 0.9884, 0.8702, 1.1338, 1.2267, 1.2355, 0.8390, 1.0043,
#         1.1235, 1.0963, 1.1474, 0.6921, 0.9283, 0.8348, 1.1194, 0.9371, 0.8698,
#         0.8661])

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 10))
ax = fig.gca(projection='3d')
# data = ch.from_numpy(np.linspace(-3.0, 3.0, 100)).unsqueeze(1).float()

ax.scatter3D(X[indices][:,0], X[indices][:,1], noised[indices], color="green", alpha=.1)
ax.scatter3D(x_trunc[:,0], x_trunc[:,1], y_trunc, color="red", alpha=.75)

ax.view_init(10, -150)
