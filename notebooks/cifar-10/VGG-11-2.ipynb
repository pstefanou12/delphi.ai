# %%
import sys
sys.path.append('../..')
import torchvision 
from torchvision import transforms
from torch.utils.data import DataLoader
import torch as ch
import torch.nn as nn
import math
import matplotlib.pyplot as plt
import cox
from cox.utils import Parameters
import cox.store as store
from cox.readers import CollectionReader
import seaborn as sns
import pickle

from delphi import train
from delphi import cifar_models
from delphi.utils.datasets import CIFAR
from delphi.utils import model_utils, defaults, data_augmentation as da, constants as consts

# %%
ds = CIFAR('/home/pstefanou/')
model, _ = model_utils.make_and_restore_model(arch='vgg11', dataset=ds)
train_loader, val_loader = ds.make_loaders(batch_size=128, workers=8)
# Out:
# ==> Preparing dataset cifar..
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# # Explore Dataset

# %%
labels = {i for i in range(10)}
for image, target in train_loader: 
    for j in range(len(target)): 
        im, targ = image[j], target[j]
        if targ.item() in labels: 
            print("label: {}".format(da.CIFAR_LABELS[targ.item()]))
            plt.imshow(transforms.ToPILImage(mode="RGB")(im.squeeze(0)))
            plt.show()
            labels.remove(targ.item())
        if len(labels) == 0: 
            break
# Out:
# label: deer
# label: bird
# label: truck
# label: horse
# label: cat
# label: dog
# label: ship
# label: frog
# label: airplane
# label: automobile

# %% [markdown]
# # Training Arguments

# %%
train_kwargs = Parameters({ 
    'lr': 1e-1, 
    'should_save_ckpt': True,
    'out_dir': '/home/pstefanou/cifar-10-vgg11',
    'adv_train': 0,
    'custom_lr_multiplier': consts.COSINE, 
    'device': 'cuda'
})
train_args = defaults.check_and_fill_args(train_kwargs, defaults.TRAINING_ARGS, CIFAR)
train_args
# Out:
# {
#   "lr": 0.1,
#   "should_save_ckpt": true,
#   "out_dir": "/home/pstefanou/cifar-10-vgg11",
#   "adv_train": 0,
#   "custom_lr_multiplier": "cosine",
#   "device": "cuda",
#   "epochs": 150,
#   "weight_decay": 0.0005,
#   "momentum": 0.9,
#   "step_lr": 50,
#   "step_lr_gamma": 0.1,
#   "lr_interpolation": "step",
#   "log_iters": 5,
#   "save_ckpt_iters": -1
# }

# %% [markdown]
# # Train Model

# %%
# logging store
out_store = store.Store(train_args.out_dir)
# model
train.train_model(train_args, model, (train_loader, val_loader), store=out_store, device=train_args.device)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=391.0), HTML(value='')))

# %%
reader = CollectionReader(train_args.out_dir)
metadata = reader.df('metadata')
logs = reader.df('logs')
reader.close()
logs.head()
# Out:
# 100%|██████████| 9/9 [00:00<00:00, 183.48it/s]
# Warning: exp_id 44c099dc-d43b-4019-851a-1e4fbe33cde1 has no table 'metadata'. Skipping.
# new schema missing keys: {'batch_size', 'shuffle', 'validation_split', 'num_workers'}, new keys: {'lr_interpolation', 'adv_train', 'step_lr_gamma', 'step_lr'}
# new schema missing keys: {'batch_size', 'shuffle', 'validation_split', 'num_workers'}, new keys: {'lr_interpolation', 'adv_train', 'step_lr_gamma', 'step_lr'}
# Warning: exp_id 1e9501fe-6b73-43ea-804a-0e4348714196 has no table 'metadata'. Skipping.
# new schema missing keys: {'batch_size', 'shuffle', 'validation_split', 'num_workers'}, new keys: {'lr_interpolation', 'adv_train', 'step_lr_gamma', 'step_lr'}
# new schema missing keys: {'batch_size', 'shuffle', 'validation_split', 'num_workers'}, new keys: {'lr_interpolation', 'adv_train', 'step_lr_gamma', 'step_lr'}
# new schema missing keys: {'batch_size', 'shuffle', 'validation_split', 'num_workers'}, new keys: {'lr_interpolation', 'adv_train', 'step_lr_gamma', 'step_lr'}
# new schema missing keys: {'batch_size', 'shuffle', 'validation_split', 'num_workers'}, new keys: {'lr_interpolation', 'adv_train', 'step_lr_gamma', 'step_lr'}
# Warning: exp_id 44c099dc-d43b-4019-851a-1e4fbe33cde1 has no table 'logs'. Skipping.
# Warning: exp_id 6b203a5a-df3e-4a44-bce2-51fdce8d39a1 has no table 'logs'. Skipping.
# Warning: exp_id dcd41e99-df0b-4b00-8478-cda962f0f6fc has no table 'logs'. Skipping.
# Warning: exp_id 1e9501fe-6b73-43ea-804a-0e4348714196 has no table 'logs'. Skipping.
# Warning: exp_id 1c38469f-9cf9-49c3-bc71-63cb6128958e has no table 'logs'. Skipping.
# Warning: exp_id 95e30c7a-5de2-4ece-87bc-5524d8455486 has no table 'logs'. Skipping.
# Warning: exp_id 8e311fbf-8d39-46b7-a158-aae0f57acd76 has no table 'logs'. Skipping.
#    epoch  val_prec1  val_loss  train_prec1  train_loss       time  \
# 0      1  21.854000  1.961156    16.302000    2.449052  12.604882
# 1      2  30.957998  1.757909    25.462000    1.873939  25.448538
# 2      3  45.531998  1.454303    38.160000    1.608956  38.439981
# 3      4  57.801998  1.166993    50.961998    1.323631  51.247648
# 4      5  63.917999  1.015980    60.427998    1.109508  64.077276
#
#                                  exp_id
# 0  41e47676-0d3f-4433-b7c4-9a4008e38662
# 1  41e47676-0d3f-4433-b7c4-9a4008e38662
# 2  41e47676-0d3f-4433-b7c4-9a4008e38662
# 3  41e47676-0d3f-4433-b7c4-9a4008e38662
# 4  41e47676-0d3f-4433-b7c4-9a4008e38662

# %% [markdown]
# # Accuracy and Loss Curves

# %%
sns.lineplot(data=logs[logs['exp_id'] == '01eb8756-856f-4120-a868-163f280b32c7'], x='epoch', y='val_prec1', label='val_prec1', color='b')
sns.lineplot(data=logs[logs['exp_id'] == '01eb8756-856f-4120-a868-163f280b32c7'], x='epoch', y='train_prec1', label='train_prec1', color='r').set_title('Accuracy Curve')
# Out:
# Text(0.5, 1.0, 'Accuracy Curve')

# %%
sns.lineplot(data=logs[logs['exp_id'] == '01eb8756-856f-4120-a868-163f280b32c7'], x='epoch', y='val_loss', label='val_loss', color='b')
sns.lineplot(data=logs[logs['exp_id'] == '01eb8756-856f-4120-a868-163f280b32c7'], x='epoch', y='train_loss', label='train_loss', color='r').set_title('Loss Curve')
# Out:
# Text(0.5, 1.0, 'Loss Curve')

# %% [markdown]
# # Load in Model

# %%
model_path = open('/home/pstefanou/cifar-10-vgg11/41e47676-0d3f-4433-b7c4-9a4008e38662/checkpoint.pt.best',"rb")
base_model = cifar_models.__dict__['vgg11'](num_classes=10)
checkpoint_dict = ch.load('/home/pstefanou/cifar-10-vgg11/41e47676-0d3f-4433-b7c4-9a4008e38662/checkpoint.pt.best')
base_model.load_state_dict(checkpoint_dict['model'])
# Out:
# <All keys matched successfully>
